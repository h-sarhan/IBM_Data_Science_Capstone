# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import folium
from bs4 import BeautifulSoup
from sklearn import preprocessing
import re

# %% [markdown]
# # Data sources
# The data sources used in this capstone are taken from:
# 1.  [New York City Neighborhood Names](https://geo.nyu.edu/catalog/nyu_2451_34572)
# 2.  [Foursquare Venue Data](https://developer.foursquare.com/docs/api/venues/details)
# 3.  [New York City Crime Rate Data](https://data.cityofnewyork.us/Public-Safety/Crime-Map-/5jvd-shfj)
# 4.  New York City Average Apartment Rental Price By Neighborhood:
#     [Manhattan](https://www.rentcafe.com/average-rent-market-trends/us/ny/manhattan/)
#     [Brooklyn](https://www.rentcafe.com/average-rent-market-trends/us/ny/brooklyn/)
#     [Bronx](https://www.rentcafe.com/average-rent-market-trends/us/ny/bronx/)
#     [Queens](https://www.rentcafe.com/average-rent-market-trends/us/ny/queens/)
# 5.  [Best New York City Neighborhoods to Live In](https://www.niche.com/places-to-live/search/best-neighborhoods/m/new-york-city-metro-area/)

# %% [markdown]
# We begin with loading the New York City Neighborhood Names data set. It is in the form of a JSON file

# %%
nynb_data_loc = './Data/New York City Neighborhoods.json'
with open(nynb_data_loc) as json_data:
    nynb_data = json.load(json_data)

# %% [markdown]
# Now we create four lists and insert all the neighborhood data from the JSON file into it

# %%
# Making four lists to house the neighborhood information into it
boroughs = []
neighborhoods = []
latitude = []
longitude = []

# This for loop goes through the json file and adds each borough,neighborhood,latitude, and longitude value to its 
# respective list  
for i in nynb_data['features']:
    boroughs.append(i['properties']['borough'])
    neighborhoods.append(i['properties']['name'])
    latitude.append(i['properties']['bbox'][1])
    longitude.append(i['properties']['bbox'][0])

# %%
# Creating the data frame that houses all the neighborhood info and then adding the 4 lists to it
NYNB = pd.DataFrame()
NYNB['Borough'] = boroughs
NYNB['Neighborhood'] = neighborhoods
NYNB['Latitude'] = latitude
NYNB['Longitude'] = longitude
NYNB
# Out:
#            Borough         Neighborhood   Latitude  Longitude
# 0            Bronx            Wakefield  40.894705 -73.847201
# 1            Bronx           Co-op City  40.874294 -73.829939
# 2            Bronx          Eastchester  40.887556 -73.827806
# 3            Bronx            Fieldston  40.895437 -73.905643
# 4            Bronx            Riverdale  40.890834 -73.912585
# 5            Bronx          Kingsbridge  40.881687 -73.902818
# 6        Manhattan          Marble Hill  40.876551 -73.910660
# 7            Bronx             Woodlawn  40.898273 -73.867315
# 8            Bronx              Norwood  40.877224 -73.879391
# 9            Bronx       Williamsbridge  40.881039 -73.857446
# 10           Bronx           Baychester  40.866858 -73.835798
# 11           Bronx       Pelham Parkway  40.857413 -73.854756
# 12           Bronx          City Island  40.847247 -73.786488
# 13           Bronx         Bedford Park  40.870185 -73.885512
# 14           Bronx   University Heights  40.855727 -73.910416
# 15           Bronx       Morris Heights  40.847898 -73.919672
# 16           Bronx              Fordham  40.860997 -73.896427
# 17           Bronx         East Tremont  40.842696 -73.887356
# 18           Bronx           West Farms  40.839475 -73.877745
# 19           Bronx         High  Bridge  40.836623 -73.926102
# 20           Bronx              Melrose  40.819754 -73.909422
# 21           Bronx           Mott Haven  40.806239 -73.916100
# 22           Bronx          Port Morris  40.801664 -73.913221
# 23           Bronx             Longwood  40.815099 -73.895788
# 24           Bronx          Hunts Point  40.809730 -73.883315
# 25           Bronx           Morrisania  40.823592 -73.901506
# 26           Bronx            Soundview  40.821012 -73.865746
# 27           Bronx         Clason Point  40.806551 -73.854144
# 28           Bronx          Throgs Neck  40.815109 -73.816350
# 29           Bronx         Country Club  40.844246 -73.824099
# ..             ...                  ...        ...        ...
# 276      Manhattan             Flatiron  40.739673 -73.990947
# 277         Queens    Sunnyside Gardens  40.745652 -73.918193
# 278         Queens           Blissville  40.737251 -73.932442
# 279       Brooklyn         Fulton Ferry  40.703281 -73.995508
# 280       Brooklyn         Vinegar Hill  40.703321 -73.981116
# 281       Brooklyn           Weeksville  40.675040 -73.930531
# 282       Brooklyn    Broadway Junction  40.677861 -73.903317
# 283       Brooklyn                Dumbo  40.703176 -73.988753
# 284  Staten Island        Manor Heights  40.601810 -74.120594
# 285  Staten Island          Willowbrook  40.603707 -74.132084
# 286  Staten Island         Sandy Ground  40.541140 -74.217766
# 287  Staten Island          Egbertville  40.579119 -74.127272
# 288         Queens              Roxbury  40.567376 -73.892138
# 289       Brooklyn            Homecrest  40.598525 -73.959185
# 290         Queens       Middle Village  40.716415 -73.881143
# 291  Staten Island         Prince's Bay  40.526264 -74.201526
# 292  Staten Island      Lighthouse Hill  40.576506 -74.137927
# 293  Staten Island      Richmond Valley  40.519541 -74.229571
# 294         Queens                Malba  40.790602 -73.826678
# 295       Brooklyn        Highland Park  40.681999 -73.890346
# 296       Brooklyn              Madison  40.609378 -73.948415
# 297          Bronx            Bronxdale  40.852723 -73.861726
# 298          Bronx             Allerton  40.865788 -73.859319
# 299          Bronx  Kingsbridge Heights  40.870392 -73.901523
# 300       Brooklyn              Erasmus  40.646926 -73.948177
# 301      Manhattan         Hudson Yards  40.756658 -74.000111
# 302         Queens              Hammels  40.587338 -73.805530
# 303         Queens            Bayswater  40.611322 -73.765968
# 304         Queens         Queensbridge  40.756091 -73.945631
# 305  Staten Island            Fox Hills  40.617311 -74.081740
#
# [306 rows x 4 columns]

# %% [markdown]
# Let us access the venue data using the Foursquare API

# %%
# Foursquare credentials
client_id = 'IMYGI0FJBA40GAV1545T4FXXVIIODTDIYBTOEDNMHIUCBN4N'
client_secret = 'TG30YWCZ031V20URB4OVXWRLEJ0LBKXUDUNOGFJQOU53K1QT'

# Function that extracts the category of a venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Let us check the nearby venues for the first neighborhood

# %%
# Coordinates of the Madison neighborhood
latitude = NYNB['Latitude'][296]
longitude = NYNB['Longitude'][296]
radius = 1000
limit = 100

# Getting the top 10 trending venues in a 500m radius from the neighborhood
url = f'https://api.foursquare.com/v2/search/recommendations?&client_id={client_id}&client_secret={client_secret}&v=20180605&ll={latitude},{longitude}&radius={radius}&limit={limit}'
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d08c2948ad62e002c20d0b3'},
#  'response': {'group': {'results': [{'displayType': 'venue',
#      'venue': {'id': '4b4b9a1ff964a5209fa126e3',
#       'name': 'Nagoya Sushi',
#       'location': {'address': '1907 Kings Hwy',
#        'crossStreet': 'at E 19th St',
#        'lat': 40.610420177453136,
#        'lng': -73.95443181531823,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.610420177453136,
#          'lng': -73.95443181531823}],
#        'distance': 521,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['1907 Kings Hwy (at E 19th St)',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1d2941735',
#         'name': 'Sushi Restaurant',
#         'pluralName': 'Sushi Restaurants',
#         'shortName': 'Sushi',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False,
#       'delivery': {'id': '72346',
#        'url': 'https://www.seamless.com/menu/nagoya-sushi-1907-kings-hwy-brooklyn/72346?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=72346',
#        'provider': {'name': 'seamless',
#         'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#          'sizes': [40, 50],
#          'name': '/delivery_provider_seamless_20180129.png'}}}},
#      'id': '5d08c29531ac6c002b2323c6',
#      'photo': {'id': '51562c54e4b0b91a29c3d5d8',
#       'createdAt': 1364601940,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/1801762_BnxRyxgoeC2xo-LAD8t3zjHQjD3Y0oJReb7t9b1rD08.jpg',
#       'width': 960,
#       'height': 720,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '50d65dd5e4b0f4384242942d',
#           'createdAt': 1356226005,
#           'text': 'Try  Crispy roll and Chicken tempura!!!',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/50d65dd5e4b0f4384242942d',
#           'likes': {'count': 1, 'groups': [], 'summary': '1 like'},
#           'logView': True,
#           'agreeCount': 1,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '43323980',
#            'firstName': 'Dimka',
#            'lastName': 'D',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/2UDTYNZN0PGGPXFO.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4c252444905a0f47fdfd6060',
#       'name': 'Pronto Pizza',
#       'location': {'address': '2928 Avenue R',
#        'lat': 40.60732679131113,
#        'lng': -73.94304067273121,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.60732679131113,
#          'lng': -73.94304067273121}],
#        'distance': 508,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['2928 Avenue R',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1ca941735',
#         'name': 'Pizza Place',
#         'pluralName': 'Pizza Places',
#         'shortName': 'Pizza',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False,
#       'delivery': {'id': '88864',
#        'url': 'https://www.seamless.com/menu/pronto-pizza-2928-ave-r-brooklyn/88864?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=88864',
#        'provider': {'name': 'seamless',
#         'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#          'sizes': [40, 50],
#          'name': '/delivery_provider_seamless_20180129.png'}}}},
#      'id': '5d08c29531ac6c002b2323c7',
#      'photo': {'id': '521bd02e11d2091096c6a2e8',
#       'createdAt': 1377554478,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/8354890_qjfU4R7WlZASQaZ7eZBGNMYTfX2nEkuiU3KifGoQnyo.jpg',
#       'width': 720,
#       'height': 960,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '4f3029fde4b0118a889d3860',
#           'createdAt': 1328556541,
#           'text': 'Get the eggplant rollatini and a chicken Alfredo pan pizza \uf60d',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/4f3029fde4b0118a889d3860',
#           'likes': {'count': 1, 'groups': [], 'summary': '1 like'},
#           'logView': True,
#           'agreeCount': 1,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '20857429',
#            'firstName': 'Donna',
#            'lastName': 'M',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/U25KTMIP1Z4T2WCP.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4bc10a9df8219c745ac0b210',
#       'name': "Michael's Pastry Shop",
#       'location': {'address': '2923 Avenue R',
#        'lat': 40.60738531197826,
#        'lng': -73.94337609670534,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.60738531197826,
#          'lng': -73.94337609670534}],
#        'distance': 480,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['2923 Avenue R',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1d0941735',
#         'name': 'Dessert Shop',
#         'pluralName': 'Dessert Shops',
#         'shortName': 'Desserts',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323c8',
#      'photo': {'id': '519bfed8498e68cf0046de73',
#       'createdAt': 1369177816,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/3045821_qgYImdKb0ivbeRoMSxF2e1G_n4MZQ5FySPd5xnhiQNQ.jpg',
#       'width': 720,
#       'height': 960,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '5157acb5e4b0af51543eb887',
#           'createdAt': 1364700341,
#           'text': 'Chocolate Mouse cake is to die for.',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/5157acb5e4b0af51543eb887',
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '2522857',
#            'firstName': 'Kathleen',
#            'lastName': 'O',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/OXWSUDUJYKV2YDVE.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4b5cba16f964a520d64029e3',
#       'name': 'Memo Shish Kebab',
#       'location': {'address': '1821 Kings Hwy',
#        'crossStreet': 'at E 19th St',
#        'lat': 40.61033215867134,
#        'lng': -73.95486474037169,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.61033215867134,
#          'lng': -73.95486474037169}],
#        'distance': 555,
#        'postalCode': '11229',
#        'cc': 'US',
#        'neighborhood': 'Sheepshead Bay',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['1821 Kings Hwy (at E 19th St)',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1c0941735',
#         'name': 'Mediterranean Restaurant',
#         'pluralName': 'Mediterranean Restaurants',
#         'shortName': 'Mediterranean',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False,
#       'delivery': {'id': '1000342',
#        'url': 'https://www.seamless.com/menu/memo-shish-kebab-1821-kings-hwy-brooklyn/1000342?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1000342',
#        'provider': {'name': 'seamless',
#         'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#          'sizes': [40, 50],
#          'name': '/delivery_provider_seamless_20180129.png'}}}},
#      'id': '5d08c29531ac6c002b2323c9',
#      'photo': {'id': '51b3e2eb498efda7d0709393',
#       'createdAt': 1370743531,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/7913426_cgeameAzqdsbB--IXEW3msTm7IuLF-Zu2jj1nQICnGY.jpg',
#       'width': 960,
#       'height': 541,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '4ff88b17e4b009b18fb88cca',
#           'createdAt': 1341688599,
#           'text': 'Chicken chops platter is always juicy, savory, and delicious! Good for 2 - 3 ppl or just for 1 hungry person.',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/4ff88b17e4b009b18fb88cca',
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '11920632',
#            'firstName': 'Rosie',
#            'lastName': 'V',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/11920632-01IRISAVG4UGFQTL.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '42508380f964a520c1201fe3',
#       'name': "Michael's",
#       'location': {'address': '2929 Avenue R',
#        'crossStreet': 'at Nostrand Ave',
#        'lat': 40.607520171283014,
#        'lng': -73.94304390996611,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.607520171283014,
#          'lng': -73.94304390996611}],
#        'distance': 498,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['2929 Avenue R (at Nostrand Ave)',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d110941735',
#         'name': 'Italian Restaurant',
#         'pluralName': 'Italian Restaurants',
#         'shortName': 'Italian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323ca',
#      'photo': {'id': '4ff55f96e4b055f8964d873b',
#       'createdAt': 1341480854,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/hlcsL8afD_-Z3VJ-KkW_VU0LSLGuykT8HE7Rqw9UbwI.jpg',
#       'width': 612,
#       'height': 612,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '58e448ecec980f256e98296d',
#           'createdAt': 1491355884,
#           'text': 'The Chilean Sea Bass is amazing and taste the scallop appetizer for a succulent starter!',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/58e448ecec980f256e98296d',
#           'likes': {'count': 1, 'groups': [], 'summary': '1 like'},
#           'logView': True,
#           'agreeCount': 1,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '10334798',
#            'firstName': 'Amy',
#            'lastName': 'C',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/U4KSWXFFHLB4QAGI.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4c1da30f01379521834647f3',
#       'name': "Dunkin'",
#       'location': {'address': '1903 Kings Hwy',
#        'crossStreet': 'btw E 19th St & Ocean Ave',
#        'lat': 40.61051996545028,
#        'lng': -73.95452012086679,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.61051996545028,
#          'lng': -73.95452012086679}],
#        'distance': 531,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['1903 Kings Hwy (btw E 19th St & Ocean Ave)',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d148941735',
#         'name': 'Donut Shop',
#         'pluralName': 'Donut Shops',
#         'shortName': 'Donuts',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False,
#       'delivery': {'id': '1162372',
#        'url': 'https://www.seamless.com/menu/dunkin-1903-kings-hwy-brooklyn/1162372?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1162372',
#        'provider': {'name': 'seamless',
#         'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#          'sizes': [40, 50],
#          'name': '/delivery_provider_seamless_20180129.png'}}}},
#      'id': '5d08c29531ac6c002b2323cb',
#      'photo': {'id': '51ba1b95498e11a3c962195c',
#       'createdAt': 1371151253,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/43231472_YOSuDn-udJjkf-nIL0_plEa-nmwSKENG3zvdsdaUXew.jpg',
#       'width': 720,
#       'height': 960,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '4f410eede4b062d5cc4791d5',
#           'createdAt': 1329663725,
#           'text': "Ask for cinnamon on top of your cappuccino, you'll love it!",
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/4f410eede4b062d5cc4791d5',
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '1074472',
#            'firstName': 'Arthur',
#            'lastName': 'V',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/0EA25J3ZIDOSKDR2.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4a5912a4f964a5209ab81fe3',
#       'name': "King's Pizza",
#       'location': {'address': '1688 E 16th St',
#        'crossStreet': 'Btw Kings Highway & Quentin Rd',
#        'lat': 40.608538749073205,
#        'lng': -73.95726770068309,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.608538749073205,
#          'lng': -73.95726770068309}],
#        'distance': 753,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['1688 E 16th St (Btw Kings Highway & Quentin Rd)',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1ca941735',
#         'name': 'Pizza Place',
#         'pluralName': 'Pizza Places',
#         'shortName': 'Pizza',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False,
#       'delivery': {'id': '286629',
#        'url': 'https://www.seamless.com/menu/kings-pizza-1688-e-16th-st-brooklyn/286629?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=286629',
#        'provider': {'name': 'seamless',
#         'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#          'sizes': [40, 50],
#          'name': '/delivery_provider_seamless_20180129.png'}}}},
#      'id': '5d08c29531ac6c002b2323cc',
#      'photo': {'id': '57681c59498ea13a2e65cbb0',
#       'createdAt': 1466440793,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/78705792_CHRemK0IfFTyPloO2kRRZ3KxjoV5l_h4n74w8N4M6_0.jpg',
#       'width': 1440,
#       'height': 1920,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '53e73696498efcb602a31402',
#           'createdAt': 1407661718,
#           'text': 'Love their margherita slice! Sooo good',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/53e73696498efcb602a31402',
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '43383075',
#            'firstName': 'Jemima',
#            'lastName': 'L',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/43383075-SI5X25ZFGKE4GOKI.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4f75aa42e4b09b052968ea8c',
#       'name': 'Marine Park Track',
#       'location': {'address': 'Fillmore Ave',
#        'crossStreet': 'at Stuart St',
#        'lat': 40.6074459029332,
#        'lng': -73.93712734958784,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.6074459029332,
#          'lng': -73.93712734958784}],
#        'distance': 977,
#        'postalCode': '11234',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['Fillmore Ave (at Stuart St)',
#         'Brooklyn, NY 11234',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d106941735',
#         'name': 'Track',
#         'pluralName': 'Tracks',
#         'shortName': 'Track',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_track_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323cd',
#      'photo': {'id': '5cdd927f83e380002c3b4c28',
#       'createdAt': 1558024831,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/3585608_-9p8m7xNpgZBLaFE1OaGWY_DD2B2Hp6ft-99ZpDO-h8.jpg',
#       'width': 1440,
#       'height': 1920,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '5997639766f3cd1dc0ba7a63',
#           'createdAt': 1503093655,
#           'text': 'Great outdoor concert area! Very spacious.',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/5997639766f3cd1dc0ba7a63',
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '2254066',
#            'firstName': 'Heather Anne Princess Of Grand Central',
#            'lastName': 'P',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/2254066_-EzgAd72_xUUejDUP-mSNcW-TRZvwM42tnL16XYqddARJ9Obl4sjS08TnKhufDI7P5H5zGIGL.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '519ae750498ec2ce85fe11d7',
#       'name': 'Highway Bagels',
#       'location': {'address': '1923 Kings Hwy',
#        'crossStreet': 'Ocean Ave',
#        'lat': 40.6106861,
#        'lng': -73.953962,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.6106861,
#          'lng': -73.953962}],
#        'distance': 490,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['1923 Kings Hwy (Ocean Ave)',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d179941735',
#         'name': 'Bagel Shop',
#         'pluralName': 'Bagel Shops',
#         'shortName': 'Bagels',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False,
#       'venuePage': {'id': '462982102'}},
#      'id': '5d08c29531ac6c002b2323ce',
#      'photo': {'id': '524ffbd411d2f9b8b8477c90',
#       'createdAt': 1380973524,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/14700354_ypQL26OCN1BP0S6vGykuNxsmccEwhiN4II06yUHzy10.jpg',
#       'width': 720,
#       'height': 960,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '5250061f11d20b9d78a05c85',
#           'createdAt': 1380976159,
#           'text': 'After trying several bagel shops, this is the best in the area. Seating area available. Nice staff.',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/5250061f11d20b9d78a05c85',
#           'likes': {'count': 1, 'groups': [], 'summary': '1 like'},
#           'logView': True,
#           'agreeCount': 2,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '14700354',
#            'firstName': 'Lucia',
#            'lastName': 'D',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/DC31H1YVA1FPXWGF.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4bf66b2e5e800f47d53fe7d4',
#       'name': 'My Favorite Bagel',
#       'location': {'address': '3053 Nostrand Ave',
#        'lat': 40.60999286911172,
#        'lng': -73.94364162614673,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.60999286911172,
#          'lng': -73.94364162614673}],
#        'distance': 409,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['3053 Nostrand Ave',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d179941735',
#         'name': 'Bagel Shop',
#         'pluralName': 'Bagel Shops',
#         'shortName': 'Bagels',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323cf',
#      'photo': {'id': '5c8527afb3d8e2002b214435',
#       'createdAt': 1552230319,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/11693984_dD9JPBHBu8IpBgZmjGmGoYIOXUEr3uuaGbLTdF-4QSY.jpg',
#       'width': 1920,
#       'height': 1440,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '50bba002e4b09b57e8974f31',
#           'createdAt': 1354473474,
#           'text': 'Awesome everything bagels. Yum!!!',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/50bba002e4b09b57e8974f31',
#           'likes': {'count': 1, 'groups': [], 'summary': '1 like'},
#           'logView': True,
#           'agreeCount': 1,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '3126514',
#            'firstName': 'Alan',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/HTE4K05TI4WXERKK.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4bae21edf964a5202f883be3',
#       'name': 'Studio 19 Salon & Spa',
#       'location': {'address': '1610 E 19th St',
#        'crossStreet': 'Kings Highway & Avenue P',
#        'lat': 40.610516406557956,
#        'lng': -73.95469145769918,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.610516406557956,
#          'lng': -73.95469145769918}],
#        'distance': 545,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['1610 E 19th St (Kings Highway & Avenue P)',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d10c951735',
#         'name': 'Cosmetics Shop',
#         'pluralName': 'Cosmetics Shops',
#         'shortName': 'Cosmetics',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False,
#       'venuePage': {'id': '33809600'}},
#      'id': '5d08c29531ac6c002b2323d0',
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '4e443e13cc3fa8acca2ad0c3',
#           'createdAt': 1313095187,
#           'text': 'The best colorist - ask for Rose.',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/4e443e13cc3fa8acca2ad0c3',
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '11834641',
#            'firstName': 'Darriel',
#            'lastName': 'S',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/Y0DIKDGQWPXEP1WU.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4d4e6e6320d3236a988e9b28',
#       'name': 'Marine Park Playground',
#       'location': {'address': 'Fillmore Ave',
#        'crossStreet': 'at Stuart St',
#        'lat': 40.607404025197226,
#        'lng': -73.9383316040039,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.607404025197226,
#          'lng': -73.9383316040039}],
#        'distance': 880,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['Fillmore Ave (at Stuart St)',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1e7941735',
#         'name': 'Playground',
#         'pluralName': 'Playgrounds',
#         'shortName': 'Playground',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323d1',
#      'photo': {'id': '5030152ae4b02982268735d2',
#       'createdAt': 1345328426,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/MOwj2tKRZBcwAsdoc7R1UrwlG2EQTjbA27FRBl3cUts.jpg',
#       'width': 612,
#       'height': 612,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '5163366de4b002d220bff19e',
#           'createdAt': 1365456493,
#           'text': 'Get here early if wanna swing',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/5163366de4b002d220bff19e',
#           'likes': {'count': 2, 'groups': [], 'summary': '2 likes'},
#           'logView': True,
#           'agreeCount': 4,
#           'disagreeCount': 0,
#           'todo': {'count': 1},
#           'user': {'id': '12068037',
#            'firstName': 'Allen',
#            'lastName': '♣',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/BETTC45V2E5UTD5C.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4b9978fef964a520f57c35e3',
#       'name': "Nora's Park Bench Cafe",
#       'location': {'address': '3019 Quentin Rd',
#        'crossStreet': 'btwn E 31st & Marine Pkwy',
#        'lat': 40.61213859800751,
#        'lng': -73.9408660129009,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.61213859800751,
#          'lng': -73.9408660129009}],
#        'distance': 708,
#        'postalCode': '11234',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['3019 Quentin Rd (btwn E 31st & Marine Pkwy)',
#         'Brooklyn, NY 11234',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d14e941735',
#         'name': 'American Restaurant',
#         'pluralName': 'American Restaurants',
#         'shortName': 'American',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323d2',
#      'photo': {'id': '5caa7b912f97ec002cb699ca',
#       'createdAt': 1554676625,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/25357808__iFq-pSkydZrwpPQJEOOrbi2BBS9a_UOIXPN-Runq0o.jpg',
#       'width': 1280,
#       'height': 1280,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '5303e4b7498ef560ddc0016c',
#           'createdAt': 1392764087,
#           'text': 'Loved the penne ala vodka and fresh mozz!!!',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/5303e4b7498ef560ddc0016c',
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '10895791',
#            'firstName': 'Joanne',
#            'lastName': 'C',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/14Q5GHJCMLKR2M1N.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4c293fc2fe6e2d7f3e97543c',
#       'name': 'Taste Of Georgia',
#       'location': {'address': '1637 E 18th St',
#        'lat': 40.60989030377894,
#        'lng': -73.95560435123909,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.60989030377894,
#          'lng': -73.95560435123909}],
#        'distance': 610,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['1637 E 18th St',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d16a941735',
#         'name': 'Bakery',
#         'pluralName': 'Bakeries',
#         'shortName': 'Bakery',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323d3',
#      'photo': {'id': '53370279498ed7ec61bd98e3',
#       'createdAt': 1396114041,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/38405371_Jk2_q79kPP4kWmHsBR3n7ayMYzibswMBmB86lc-W-S4.jpg',
#       'width': 640,
#       'height': 640,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '5442f4dd498e9c9e243549b0',
#           'createdAt': 1413674205,
#           'text': 'At weekends they make great "achma" pie',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/5442f4dd498e9c9e243549b0',
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '38405371',
#            'firstName': 'leo',
#            'lastName': 'k',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/38405371_Oa1Buj2q__4SCAe3yrUrWLRYjzLw9ADUFwI_INhm4WNkXdUSpC_QyiO0gelLsWxYBZOBeBE92.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4b26d8d7f964a520e28124e3',
#       'name': "Buckley's Restaurant and Catering",
#       'location': {'address': '2926 Avenue S',
#        'crossStreet': 'at Nostrand Ave.',
#        'lat': 40.605006797156975,
#        'lng': -73.94303131001274,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.605006797156975,
#          'lng': -73.94303131001274}],
#        'distance': 666,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['2926 Avenue S (at Nostrand Ave.)',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d14e941735',
#         'name': 'American Restaurant',
#         'pluralName': 'American Restaurants',
#         'shortName': 'American',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False,
#       'venuePage': {'id': '70529382'}},
#      'id': '5d08c29531ac6c002b2323d4',
#      'photo': {'id': '5120340de4b0841ee617949d',
#       'createdAt': 1361064973,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/1395682_0bSnpOB_RohWVeqcAYvkpqEJrBN98rQm9aKZdcucMQI.jpg',
#       'width': 959,
#       'height': 717,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '583a21281e1de544a8c9f4af',
#           'createdAt': 1480204584,
#           'text': 'Steak is great, company excellent! Staff so friendly. Sat with Jackie and had dessert, nice guy! Happy Holidays!',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/583a21281e1de544a8c9f4af',
#           'likes': {'count': 1, 'groups': [], 'summary': '1 like'},
#           'logView': True,
#           'agreeCount': 2,
#           'disagreeCount': 0,
#           'lastVoteText': 'Upvoted 4 weeks ago',
#           'lastUpvoteTimestamp': 1558222483,
#           'todo': {'count': 0},
#           'user': {'id': '340067121',
#            'firstName': 'Mary',
#            'lastName': 'J',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/340067121-2N40UZFTQSIKFQ15.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '5589e005498e2fb39c719146',
#       'name': 'Chipotle Mexican Grill',
#       'location': {'address': '1325 Kings Hwy',
#        'lat': 40.60849875894529,
#        'lng': -73.95935606440071,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.60849875894529,
#          'lng': -73.95935606440071}],
#        'distance': 929,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['1325 Kings Hwy',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d153941735',
#         'name': 'Burrito Place',
#         'pluralName': 'Burrito Places',
#         'shortName': 'Burritos',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323d5',
#      'photo': {'id': '5cad38e425fb7b002c3656cc',
#       'createdAt': 1554856164,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/87388367_HYuT0MaZVSXfoIRv-_Ng-W3E0HM39sjRWOBTzFk9CCo.jpg',
#       'width': 619,
#       'height': 619,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '5597e04c498e5272bac2f117',
#           'createdAt': 1436016716,
#           'text': "Burrito bowl and make it a double if you're hungry. The guacamole is real and fresh.",
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/5597e04c498e5272bac2f117',
#           'likes': {'count': 1, 'groups': [], 'summary': '1 like'},
#           'logView': True,
#           'agreeCount': 2,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '52266',
#            'firstName': 'Eitan',
#            'lastName': 'L',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/CM24LWYKKOSUWWV4.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4b37ad43f964a520244425e3',
#       'name': 'Natural Balance Massage & Wellness Center',
#       'location': {'address': '3013 Quentin Rd',
#        'crossStreet': 'btwn Marine Pkwy & East 31st St.',
#        'lat': 40.612069602556964,
#        'lng': -73.94102089424322,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.612069602556964,
#          'lng': -73.94102089424322}],
#        'distance': 693,
#        'postalCode': '11234',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['3013 Quentin Rd (btwn Marine Pkwy & East 31st St.)',
#         'Brooklyn, NY 11234',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1ed941735',
#         'name': 'Spa',
#         'pluralName': 'Spas',
#         'shortName': 'Spa',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False,
#       'venuePage': {'id': '37689396'}},
#      'id': '5d08c29531ac6c002b2323d6',
#      'photo': {'id': '52698d8a498eec2a244a9f65',
#       'createdAt': 1382649226,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/37689396_iDmgaTGx53eH1XzBvVIOB9diihrX2QstcUNndQcDvCg.jpg',
#       'width': 1663,
#       'height': 1155,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '512e6e62e4b01d7d37c44300',
#           'createdAt': 1361997410,
#           'text': "If you aren't on the guest book's mailing list, you will miss out on upcoming announcements for our 20th anniversary events and specials, starting with a Health Fair in April 2013!",
#           'type': 'user',
#           'url': 'https://www.salonbuilder.com/website/148610/guestbook.asp',
#           'canonicalUrl': 'https://foursquare.com/item/512e6e62e4b01d7d37c44300',
#           'likes': {'count': 1, 'groups': [], 'summary': '1 like'},
#           'logView': True,
#           'agreeCount': 1,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '1071100',
#            'firstName': 'Linda',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/K2VEVLFHAW5KLNYH.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4cd2f57125ee6dcb7054470f',
#       'name': 'Aksaray Gyro',
#       'location': {'address': '1618 E 16th St',
#        'crossStreet': 'Ave P',
#        'lat': 40.60992419079359,
#        'lng': -73.95757702956708,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.60992419079359,
#          'lng': -73.95757702956708}],
#        'distance': 776,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['1618 E 16th St (Ave P)',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d115941735',
#         'name': 'Middle Eastern Restaurant',
#         'pluralName': 'Middle Eastern Restaurants',
#         'shortName': 'Middle Eastern',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323d7',
#      'photo': {'id': '5b80b20061f070002c246f3b',
#       'createdAt': 1535160832,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/511039038_YcgrE1pz79qZk0awi8I70JbdAr1ahFX2abkRsUGxedA.jpg',
#       'width': 1440,
#       'height': 1920,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '576de818498ef8c95de57c58',
#           'createdAt': 1466820632,
#           'text': 'Can get a kebab at any time',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/576de818498ef8c95de57c58',
#           'logView': True,
#           'agreeCount': 2,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '91127115',
#            'firstName': 'Da mi',
#            'lastName': 'L',
#            'gender': 'none',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/blank_boy.png',
#             'default': True}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '49f21e71f964a520e6691fe3',
#       'name': 'Cafe Hadar',
#       'location': {'address': '2923 Avenue N',
#        'crossStreet': '29th St',
#        'lat': 40.617410422292224,
#        'lng': -73.9453687346826,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.617410422292224,
#          'lng': -73.9453687346826}],
#        'distance': 930,
#        'postalCode': '11210',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['2923 Avenue N (29th St)',
#         'Brooklyn, NY 11210',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323d8',
#      'photo': {'id': '5acec43cf5e9d76052e65b41',
#       'createdAt': 1523500092,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/18672613_WcI2Revr84vgZH4dFeHgYJfqXKFjvEonYHEHkVOeJcM.jpg',
#       'width': 1080,
#       'height': 1920,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '5853fcbb00841a70361ee135',
#           'createdAt': 1481899195,
#           'text': 'The roasted beet salad with added salmon is yummy, as are the stuffed mushroom caps. The peanut butter mousse was the lightest mousse I have ever had.',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/5853fcbb00841a70361ee135',
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '455484',
#            'firstName': 'Deb',
#            'lastName': 'W',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/TAI3QOGLMKDAAHY3.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '5b9aaf945d891b002c773dcf',
#       'name': 'Planet Fitness',
#       'location': {'address': '1601 Kings Hwy',
#        'crossStreet': 'at 16th St',
#        'lat': 40.60939583215033,
#        'lng': -73.95703109099586,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.60939583215033,
#          'lng': -73.95703109099586}],
#        'distance': 728,
#        'postalCode': '11229',
#        'cc': 'US',
#        'neighborhood': 'Sheepshead Bay',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['1601 Kings Hwy (at 16th St)',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d175941735',
#         'name': 'Gym / Fitness Center',
#         'pluralName': 'Gyms or Fitness Centers',
#         'shortName': 'Gym / Fitness',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323d9',
#      'snippets': {'count': 1, 'items': [{}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4baacdddf964a52099873ae3',
#       'name': 'T Fusion Steakhouse',
#       'location': {'address': '3223 Quentin Rd',
#        'crossStreet': 'at E 33rd St',
#        'lat': 40.61331925173722,
#        'lng': -73.93915420782331,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.61331925173722,
#          'lng': -73.93915420782331}],
#        'distance': 897,
#        'postalCode': '11234',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['3223 Quentin Rd (at E 33rd St)',
#         'Brooklyn, NY 11234',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1cc941735',
#         'name': 'Steakhouse',
#         'pluralName': 'Steakhouses',
#         'shortName': 'Steakhouse',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False,
#       'venuePage': {'id': '67516353'}},
#      'id': '5d08c29531ac6c002b2323da',
#      'photo': {'id': '523b7eb0bce66b2e6a06a6a8',
#       'createdAt': 1379630768,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/67123895_id9ZC6os2HkBOEAKiqo8gBzqabfSfo-v-iol9a64XwU.jpg',
#       'width': 612,
#       'height': 816,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '565a327a498e744f465719ec',
#           'createdAt': 1448751738,
#           'text': 'The BBQ ribs are huge & very good.',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/565a327a498e744f465719ec',
#           'likes': {'count': 1, 'groups': [], 'summary': '1 like'},
#           'logView': True,
#           'agreeCount': 1,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '674507',
#            'firstName': 'Shay',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/NFFIXM5D4EYBCMAI.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4eccd8d5f7908e99a1a31593',
#       'name': 'Jazz. Club',
#       'location': {'lat': 40.61530735813873,
#        'lng': -73.95474991497144,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.61530735813873,
#          'lng': -73.95474991497144}],
#        'distance': 849,
#        'postalCode': '11230',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['Brooklyn, NY 11230', 'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1e7931735',
#         'name': 'Jazz Club',
#         'pluralName': 'Jazz Clubs',
#         'shortName': 'Jazz Club',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323db',
#      'photo': {'id': '56edf73e498e84241a549ea9',
#       'createdAt': 1458435902,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/137360104_o1xV4-0dnXvdkLUqfFQGfEHON9zh7CnoIM7OdXyMRqY.jpg',
#       'width': 1440,
#       'height': 1920,
#       'visibility': 'public'},
#      'snippets': {'count': 1, 'items': [{}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4c43447de26920a1803861e7',
#       'name': "King's Gourmet Food",
#       'location': {'address': '1508 Kings Hwy',
#        'crossStreet': 'Between 15&16 streets',
#        'lat': 40.60885500208042,
#        'lng': -73.95799234887735,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.60885500208042,
#          'lng': -73.95799234887735}],
#        'distance': 811,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['1508 Kings Hwy (Between 15&16 streets)',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1f5941735',
#         'name': 'Gourmet Shop',
#         'pluralName': 'Gourmet Shops',
#         'shortName': 'Gourmet',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323dc',
#      'photo': {'id': '518d7e19498ee8290f1dce57',
#       'createdAt': 1368227353,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/777902_NzOD8U4oVcDpJEfaBgFq-vpP4u_kOtPxsXKIrKXy_l4.jpg',
#       'width': 1920,
#       'height': 1440,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
# ...
#       'name': 'Gorgeous Nail & Beauty Salon',
#       'location': {'address': '2916 Avenue R',
#        'lat': 40.60725510120392,
#        'lng': -73.943545,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.60725510120392,
#          'lng': -73.943545}],
#        'distance': 474,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['2916 Avenue R',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1ed941735',
#         'name': 'Spa',
#         'pluralName': 'Spas',
#         'shortName': 'Spa',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323fd',
#      'photo': {'id': '5150b2e7e4b0fc61723a6f72',
#       'createdAt': 1364243175,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/2464584_7JMc4Gy1dAulPTTEV-KydJEFaaDg_DaRvBt0Ia6aonM.jpg',
#       'width': 960,
#       'height': 717,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '523dd11211d215e4a28f0cfa',
#           'createdAt': 1379782930,
#           'text': 'Inexpensive Mani pedi at $15',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/523dd11211d215e4a28f0cfa',
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '62628098',
#            'firstName': 'Nancy',
#            'lastName': 'N',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/LWMTMDKS05PZER4D.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4bec869875b2c9b6c9a2438d',
#       'name': 'Met Food',
#       'location': {'address': '3404 Quentin Rd',
#        'crossStreet': 'at E 34th St',
#        'lat': 40.6138203705362,
#        'lng': -73.93811738716033,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.6138203705362,
#          'lng': -73.93811738716033}],
#        'distance': 1000,
#        'postalCode': '11234',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['3404 Quentin Rd (at E 34th St)',
#         'Brooklyn, NY 11234',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d118951735',
#         'name': 'Grocery Store',
#         'pluralName': 'Grocery Stores',
#         'shortName': 'Grocery Store',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323fe',
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '5a1b0f10ca18ea02911a6a67',
#           'createdAt': 1511722768,
#           'text': 'Great meat and produce sections beside a good selection of groceries',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/5a1b0f10ca18ea02911a6a67',
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '16247439',
#            'firstName': 'RoseMarie',
#            'lastName': 'D',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/CDSSA0YNGPQSMZUB.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4cd1c1ad5b5ca35ddb6183f0',
#       'name': 'modern nails',
#       'location': {'lat': 40.607382268797515,
#        'lng': -73.94301128360219,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.607382268797515,
#          'lng': -73.94301128360219}],
#        'distance': 507,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['Brooklyn, NY 11229', 'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1ed941735',
#         'name': 'Spa',
#         'pluralName': 'Spas',
#         'shortName': 'Spa',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b2323ff',
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '4fc14a8ae4b08acecb682d61',
#           'createdAt': 1338067594,
#           'text': 'New pedicure chairs FABULOUS',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/4fc14a8ae4b08acecb682d61',
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '19861413',
#            'firstName': 'Donna',
#            'lastName': 'J',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/19861413-BTDAFM3SOVMMHWZS.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4ee25b379adf48bc19f80f3a',
#       'name': 'MTA Bus - B7/B82',
#       'location': {'address': 'Kings Highway',
#        'crossStreet': 'East 22nd Street',
#        'lat': 40.60969941423441,
#        'lng': -73.95568553070673,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.60969941423441,
#          'lng': -73.95568553070673}],
#        'distance': 615,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['Kings Highway (East 22nd Street)',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1fe931735',
#         'name': 'Bus Station',
#         'pluralName': 'Bus Stations',
#         'shortName': 'Bus Station',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b232400',
#      'photo': {'id': '569d4d9c498e9972e335ee5c',
#       'createdAt': 1453149596,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/86156591_kMxG6zW0d6FrxKiFmt86qjiFMKo0r4QggusMGdXrpvE.jpg',
#       'width': 960,
#       'height': 539,
#       'visibility': 'public'},
#      'snippets': {'count': 1, 'items': [{}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4e25d49ab0fbf642a902ba66',
#       'name': 'Nova Wine',
#       'location': {'lat': 40.605098724365234,
#        'lng': -73.94297790527344,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.605098724365234,
#          'lng': -73.94297790527344}],
#        'distance': 661,
#        'cc': 'US',
#        'state': 'New York',
#        'country': 'United States',
#        'formattedAddress': ['New York', 'United States']},
#       'categories': [{'id': '4bf58dd8d48988d186941735',
#         'name': 'Liquor Store',
#         'pluralName': 'Liquor Stores',
#         'shortName': 'Liquor Store',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b232401',
#      'photo': {'id': '54b16386498e8bcf64a9b47d',
#       'createdAt': 1420911494,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/3045821_BRrnlzqNfnSI4wOiUxuj800-DlZGcLyLubTYpv2Wvno.jpg',
#       'width': 1439,
#       'height': 1920,
#       'visibility': 'public'},
#      'snippets': {'count': 1, 'items': [{}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4de2fda8ae60e7f3abfde450',
#       'name': 'MTA Bus - B44- Nostrand Avenue & Avenue R',
#       'location': {'address': 'Nostrand Avenue & Avenue R',
#        'lat': 40.609238207823964,
#        'lng': -73.94050274042353,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.609238207823964,
#          'lng': -73.94050274042353}],
#        'distance': 668,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['Nostrand Avenue & Avenue R',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1fe931735',
#         'name': 'Bus Station',
#         'pluralName': 'Bus Stations',
#         'shortName': 'Bus Station',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b232402',
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '4eb2dafd93ad74b3b94506b5',
#           'createdAt': 1320344317,
#           'text': 'Limited buses that are empty are always on Ave U towards Nostrand',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/4eb2dafd93ad74b3b94506b5',
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '15411377',
#            'firstName': 'SarahLevv',
#            'lastName': 'x',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/Z31JZHZMAKEQG2JQ.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4bb412a0737d76b0531f3b7c',
#       'name': 'Bullseye Sports Pub',
#       'location': {'address': '3121 Quentin Rd',
#        'crossStreet': 'E 32nd',
#        'lat': 40.61276986226537,
#        'lng': -73.93987077236416,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.61276986226537,
#          'lng': -73.93987077236416}],
#        'distance': 814,
#        'postalCode': '11234',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['3121 Quentin Rd (E 32nd)',
#         'Brooklyn, NY 11234',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d116941735',
#         'name': 'Bar',
#         'pluralName': 'Bars',
#         'shortName': 'Bar',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b232403',
#      'photo': {'id': '4f07c485e4b05f830cd930ef',
#       'createdAt': 1325909125,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/LJCRU12HHPURDGY2FECSWOHAW3ZYRIHNRPBPZJCOXTKJ531Q.jpg',
#       'width': 431,
#       'height': 720,
#       'visibility': 'public'},
#      'snippets': {'count': 1, 'items': [{}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4cc46d6180624688a264362f',
#       'name': 'Hair Service Barbers Inc',
#       'location': {'address': '2912 Avenue T',
#        'lat': 40.6026354252822,
#        'lng': -73.94284017732447,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.6026354252822,
#          'lng': -73.94284017732447}],
#        'distance': 886,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['2912 Avenue T',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d10c951735',
#         'name': 'Cosmetics Shop',
#         'pluralName': 'Cosmetics Shops',
#         'shortName': 'Cosmetics',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b232404',
#      'photo': {'id': '50242c2be4b0397f315d52be',
#       'createdAt': 1344547883,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/g6pfXPahtnjD_36zpwa9ttShaU9SurupX5HPNlz1iYs.jpg',
#       'width': 405,
#       'height': 540,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '4cc5a07f9eeab7137ce7e040',
#           'createdAt': 1288020095,
#           'text': 'Best barbers in NY... Weather you get your cut from Blak, Westbay or Andreas you cant go wrong and the razor at the end makes your haircut look fresh for days',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/4cc5a07f9eeab7137ce7e040',
#           'likes': {'count': 1, 'groups': [], 'summary': '1 like'},
#           'logView': True,
#           'agreeCount': 2,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '416069',
#            'firstName': 'Eugene',
#            'lastName': 'P',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/VSVG5W41VVJLXUKE.jpg'}}}}}]}},
#     {'displayType': 'venue',
#      'venue': {'id': '4eb30c6ddab4b138c5b7763e',
#       'name': 'Soft Touch Laser Hair Removal',
#       'location': {'address': '1414 Avenue P, Brooklyn, NY 11229',
#        'lat': 40.601437473902884,
#        'lng': -73.95152401492838,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.601437473902884,
#          'lng': -73.95152401492838}],
#        'distance': 922,
#        'postalCode': '11229',
#        'cc': 'US',
#        'city': 'Brooklyn',
#        'state': 'NY',
#        'country': 'United States',
#        'formattedAddress': ['1414 Avenue P, Brooklyn, NY 11229',
#         'Brooklyn, NY 11229',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1ed941735',
#         'name': 'Spa',
#         'pluralName': 'Spas',
#         'shortName': 'Spa',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#          'suffix': '.png'},
#         'primary': True}],
#       'dislike': False,
#       'ok': False},
#      'id': '5d08c29531ac6c002b232405',
#      'photo': {'id': '4fd8e0fee4b0a9a89f32941d',
#       'createdAt': 1339613438,
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/b6tJ9b-OfThowJ3tiCSUd0kCNivZ-MY8fCbHz0x68-Y.jpg',
#       'width': 720,
#       'height': 540,
#       'visibility': 'public'},
#      'snippets': {'count': 1,
#       'items': [{'detail': {'type': 'tip',
#          'object': {'id': '51645079e4b02e16b3c01ede',
#           'createdAt': 1365528697,
#           'text': 'The ladies that work here are super cool and friendly. Love this place.',
#           'type': 'user',
#           'canonicalUrl': 'https://foursquare.com/item/51645079e4b02e16b3c01ede',
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'user': {'id': '1488695',
#            'firstName': 'funky',
#            'lastName': 'f',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/1488695-H3T5GXLTD5ULDDDG.jpg'}}}}}]}}],
#    'totalResults': 64},
#   'context': {'searchLocationNearYou': True,
#    'searchLocationMapBounds': False,
#    'searchLocationType': 'NearYou',
#    'currentLocation': {'what': '',
#     'where': '',
#     'feature': {'cc': 'US',
#      'name': 'Madison',
#      'displayName': 'Madison, Brooklyn, NY',
#      'woeType': 22,
#      'id': 'maponics:190607',
#      'longId': '190607',
#      'geometry': {'center': {'lat': 40.606602, 'lng': -73.947633},
#       'bounds': {'ne': {'lat': 40.6160477, 'lng': -73.9418943},
#        'sw': {'lat': 40.5993787, 'lng': -73.953585}}},
#      'encumbered': True},
#     'parents': []},
#    'boundsSummaryRadius': 1000,
#    'relatedNeighborhoods': [],
#    'geoParams': {'ll': '40.60937770113766,-73.94841515328893',
#     'radius': '1000'},
#    'geoBounds': {'circle': {'center': {'lat': 40.60937770113766,
#       'lng': -73.94841515328893},
#      'radius': 1000}}}}}

# %% [markdown]
# Cleaning the JSON file

# %%
venues = results['response']['group']['results']
venues
nearby_venues = json_normalize(venues) # flatten JSON

filtered_columns = ['venue.name', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

# %%
nearby_venues
# Out:
#                                          name        lat        lng
# 0                                Nagoya Sushi  40.610420 -73.954432
# 1                                Pronto Pizza  40.607327 -73.943041
# 2                       Michael's Pastry Shop  40.607385 -73.943376
# 3                            Memo Shish Kebab  40.610332 -73.954865
# 4                                   Michael's  40.607520 -73.943044
# 5                                     Dunkin'  40.610520 -73.954520
# 6                                King's Pizza  40.608539 -73.957268
# 7                           Marine Park Track  40.607446 -73.937127
# 8                              Highway Bagels  40.610686 -73.953962
# 9                           My Favorite Bagel  40.609993 -73.943642
# 10                      Studio 19 Salon & Spa  40.610516 -73.954691
# 11                     Marine Park Playground  40.607404 -73.938332
# 12                     Nora's Park Bench Cafe  40.612139 -73.940866
# 13                           Taste Of Georgia  40.609890 -73.955604
# 14          Buckley's Restaurant and Catering  40.605007 -73.943031
# 15                     Chipotle Mexican Grill  40.608499 -73.959356
# 16  Natural Balance Massage & Wellness Center  40.612070 -73.941021
# 17                               Aksaray Gyro  40.609924 -73.957577
# 18                                 Cafe Hadar  40.617410 -73.945369
# 19                             Planet Fitness  40.609396 -73.957031
# 20                        T Fusion Steakhouse  40.613319 -73.939154
# 21                                 Jazz. Club  40.615307 -73.954750
# 22                        King's Gourmet Food  40.608855 -73.957992
# 23                             Vitamin Shoppe  40.608147 -73.959269
# 24                          Harbor Fitness GO  40.615389 -73.944461
# 25                                Kings Games  40.608363 -73.958103
# 26                             Baskin-Robbins  40.610324 -73.954509
# 27                                   T-Mobile  40.608739 -73.958849
# 28                              AT&T Brooklyn  40.610656 -73.954244
# 29                               CVS pharmacy  40.609305 -73.957301
# ..                                        ...        ...        ...
# 34                                  Starbucks  40.608782 -73.958597
# 35                              Sushi Meshuga  40.609858 -73.956562
# 36                                  T.J. Maxx  40.609567 -73.958715
# 37                                        GNC  40.608391 -73.958997
# 38                                 Big Banana  40.609801 -73.956072
# 39                                     Target  40.607687 -73.959237
# 40                                  J&R Pizza  40.610440 -73.954174
# 41                                    Dunkin'  40.608479 -73.958450
# 42                       Perizia Kosher Pizza  40.609770 -73.957555
# 43                        Hot Bagels & Bialys  40.609302 -73.956925
# 44                                    Dunkin'  40.614143 -73.949859
# 45                                Duane Reade  40.608629 -73.959012
# 46                       The Children's Place  40.608346 -73.959577
# 47                         Domino Supermarket  40.610153 -73.954934
# 48                                    Verizon  40.609610 -73.956806
# 49                                    iKimchi  40.608761 -73.958596
# 50                                 Pizza Nosh  40.615756 -73.944672
# 51                       New York Sports Club  40.609547 -73.958583
# 52                  Sunflower Cafe - Brooklyn  40.608049 -73.960099
# 53                                   Rite Aid  40.609621 -73.955799
# 54                               CVS pharmacy  40.616364 -73.945091
# 55               Gorgeous Nail & Beauty Salon  40.607255 -73.943545
# 56                                   Met Food  40.613820 -73.938117
# 57                               modern nails  40.607382 -73.943011
# 58                           MTA Bus - B7/B82  40.609699 -73.955686
# 59                                  Nova Wine  40.605099 -73.942978
# 60  MTA Bus - B44- Nostrand Avenue & Avenue R  40.609238 -73.940503
# 61                        Bullseye Sports Pub  40.612770 -73.939871
# 62                   Hair Service Barbers Inc  40.602635 -73.942840
# 63              Soft Touch Laser Hair Removal  40.601437 -73.951524
#
# [64 rows x 3 columns]

# %% [markdown]
# Now that we have all the venues for one neighborhood let us create a function to get all the venues for all the neighborhoods

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        url = f'https://api.foursquare.com/v2/search/recommendations?&client_id={client_id}&client_secret={client_secret}&v=20180605&ll={lat},{lng}&radius={radius}&limit=100'
        results = requests.get(url).json()["response"]['group']['results']        
        venues_list.append([(name, v['venue']['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 'Venue']
    
    return(nearby_venues)

# %% [markdown]
# Since we have over 300 neighborhoods lets use this function later on when the list of neighborhoods gets smaller.
#
# Now its time to collect information on New York City's criminal activity.
# The next data set comes from the city of New York and it shows crimes and the locations of where the crimes occured

# %%
crime_data = pd.read_csv('./Data/New York City Crimes.csv')
crime_data.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM      RPT_DT  \
# 0   251527331   03/31/2019     23:50:00   04/01/2019     00:10:00  03/31/2019
# 1   440213705   03/31/2019     23:50:00   04/01/2019     00:10:00  03/31/2019
# 2   607477539   03/31/2019     23:00:00   03/31/2019     23:15:00  03/31/2019
# 3   356729172   03/31/2019     23:00:00   03/31/2019     23:05:00  03/31/2019
# 4   225899019   03/31/2019     23:00:00   03/31/2019     23:05:00  03/31/2019
#
#    KY_CD                       OFNS_DESC  PD_CD  \
# 0    344    ASSAULT 3 & RELATED OFFENSES  101.0
# 1    344    ASSAULT 3 & RELATED OFFENSES  101.0
# 2    106                  FELONY ASSAULT  109.0
# 3    126         MISCELLANEOUS PENAL LAW  198.0
# 4    351  CRIMINAL MISCHIEF & RELATED OF  259.0
#
#                             PD_DESC  ... ADDR_PCT_CD LOC_OF_OCCUR_DESC  \
# 0                         ASSAULT 3  ...         114            INSIDE
# 1                         ASSAULT 3  ...         114          FRONT OF
# 2          ASSAULT 2,1,UNCLASSIFIED  ...          45            INSIDE
# 3               CRIMINAL CONTEMPT 1  ...         109            INSIDE
# 4  CRIMINAL MISCHIEF,UNCLASSIFIED 4  ...          46          FRONT OF
#
#                 PREM_TYP_DESC PARKS_NM       HADEVELOPT X_COORD_CD Y_COORD_CD  \
# 0  RESIDENCE - PUBLIC HOUSING      NaN              NaN  1001557.0   217404.0
# 1  RESIDENCE - PUBLIC HOUSING      NaN              NaN  1001557.0   217404.0
# 2             RESIDENCE-HOUSE      NaN              NaN  1026297.0   244171.0
# 3  RESIDENCE - PUBLIC HOUSING      NaN  LATIMER GARDENS  1031088.0   218649.0
# 4      RESIDENCE - APT. HOUSE      NaN              NaN  1005725.0   249742.0
#
#     Latitude  Longitude                                   Lat_Lon
# 0  40.763391 -73.937525   (40.76339148500005, -73.93752515999995)
# 1  40.763391 -73.937525   (40.76339148500005, -73.93752515999995)
# 2  40.836776 -73.848049  (40.836776445000055, -73.84804910999998)
# 3  40.766702 -73.830913  (40.766701556000044, -73.83091313699998)
# 4  40.852141 -73.922376   (40.85214118700002, -73.92237572199997)
#
# [5 rows x 24 columns]

# %% [markdown]
# Thats a lot of columns. Lets take a look at a list of all the columns and see what interests us

# %%
crime_data.columns.values
# Out:
# array(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
#        'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
#        'HADEVELOPT', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lat_Lon'], dtype=object)

# %% [markdown]
# We are interested in the Borough, Latitude, and Longitude columns

# %%
crime_data = crime_data[['BORO_NM','Latitude', 'Longitude']]
crime_data
# Out:
#               BORO_NM   Latitude  Longitude
# 0              QUEENS  40.763391 -73.937525
# 1              QUEENS  40.763391 -73.937525
# 2               BRONX  40.836776 -73.848049
# 3              QUEENS  40.766702 -73.830913
# 4               BRONX  40.852141 -73.922376
# 5               BRONX  40.822570 -73.911307
# 6              QUEENS  40.677605 -73.828219
# 7           MANHATTAN  40.745227 -74.004116
# 8               BRONX  40.805226 -73.914747
# 9              QUEENS  40.580403 -73.831536
# 10           BROOKLYN  40.685875 -73.917777
# 11             QUEENS  40.691015 -73.811525
# 12           BROOKLYN  40.650683 -73.963311
# 13      STATEN ISLAND  40.626315 -74.144605
# 14           BROOKLYN  40.670350 -73.988725
# 15           BROOKLYN  40.675412 -73.871915
# 16             QUEENS  40.766729 -73.912692
# 17             QUEENS  40.688227 -73.797636
# 18           BROOKLYN  40.696847 -73.936509
# 19              BRONX  40.836404 -73.866184
# 20              BRONX  40.806831 -73.917480
# 21           BROOKLYN  40.653675 -73.962787
# 22          MANHATTAN  40.715921 -74.010106
# 23             QUEENS  40.712989 -73.907467
# 24          MANHATTAN  40.758618 -73.983209
# 25      STATEN ISLAND  40.647128 -74.088181
# 26             QUEENS  40.712989 -73.907467
# 27           BROOKLYN  40.598774 -73.937236
# 28          MANHATTAN  40.835945 -73.941584
# 29              BRONX  40.805504 -73.916477
# ...               ...        ...        ...
# 105039         QUEENS  40.593685 -73.759070
# 105040  STATEN ISLAND  40.605063 -74.065438
# 105041  STATEN ISLAND  40.613282 -74.067729
# 105042       BROOKLYN  40.628623 -73.986034
# 105043      MANHATTAN  40.750297 -73.996710
# 105044  STATEN ISLAND  40.595735 -74.107288
# 105045       BROOKLYN  40.686952 -73.947531
# 105046  STATEN ISLAND  40.554628 -74.173127
# 105047         QUEENS  40.711849 -73.754080
# 105048       BROOKLYN  40.606697 -73.982347
# 105049         QUEENS  40.698677 -73.830249
# 105050         QUEENS  40.680003 -73.764022
# 105051          BRONX  40.824691 -73.860871
# 105052         QUEENS  40.771533 -73.815362
# 105053      MANHATTAN  40.784051 -73.948704
# 105054       BROOKLYN  40.651981 -73.919052
# 105055       BROOKLYN  40.597781 -73.956203
# 105056       BROOKLYN  40.689156 -73.981557
# 105057      MANHATTAN  40.751275 -73.982500
# 105058       BROOKLYN  40.648648 -73.967731
# 105059      MANHATTAN  40.793019 -73.974847
# 105060       BROOKLYN  40.706222 -73.950974
# 105061      MANHATTAN  40.848128 -73.930885
# 105062       BROOKLYN  40.612279 -73.978841
# 105063       BROOKLYN  40.644769 -73.999929
# 105064      MANHATTAN  40.864136 -73.919180
# 105065      MANHATTAN  40.832942 -73.935433
# 105066         QUEENS  40.762334 -73.826917
# 105067       BROOKLYN  40.684645 -73.974102
# 105068      MANHATTAN  40.866063 -73.919297
#
# [105069 rows x 3 columns]

# %% [markdown]
# Let us clean the data a little bit

# %%
crime_data['BORO_NM'].dropna(axis = 0, inplace = True)
crime_data['BORO_NM'] = crime_data['BORO_NM'].apply(lambda x : x.capitalize())

# %%
crime_data.rename({'BORO_NM' : 'Crime_Borough', 'Latitude' : 'Crime_Latitude', 'Longitude' : 'Crime_Longitude'}, axis = 1,inplace = True)

# %%
crime_data.shape
# Out:
# (105069, 3)

# %% [markdown]
# This is a very large data set (OVER 100,000!) for our purposes we dont need a dataset this large so lets just use the first 1000 crimes

# %%
crime_data = crime_data[0:1000]

# %% [markdown]
# Now you may have noticed that the crime_data dataframe does not have a neighborhood column. No need to worry we can use LocationIQ's reverse geocoding service to find the neighborhood name for each coordinate pair

# %%
# LocationIQ credentials
access_token = 'pk.be0335719a45f97e8715b8e81c1f4820'

# Let's get the neigjborhood for the first crime
crime_lat = crime_data['Crime_Latitude'][0]
crime_long = crime_data['Crime_Longitude'][0]
url = f'https://us1.locationiq.com/v1/reverse.php?key={access_token}&lat={crime_lat}&lon={crime_long}&format=json'
results = requests.get(url).json()
results
# Out:
# {'place_id': '333233966211',
#  'licence': 'https://locationiq.com/attribution',
#  'lat': '40.763563',
#  'lon': '-73.937785',
#  'display_name': '34-28, 12 St, Long Island City, New York, Queens County, New York, United States, 11106',
#  'boundingbox': ['40.763563', '40.763563', '-73.937785', '-73.937785'],
#  'importance': 0.2,
#  'address': {'house_number': '34-28',
#   'road': '12 St',
#   'neighbourhood': 'Long Island City',
#   'city': 'New York',
#   'county': 'Queens County',
#   'state': 'New York',
#   'country': 'United States',
#   'postcode': '11106',
#   'country_code': 'us'}}

# %% [markdown]
# Now we extract the neighborhood data from the JSON result

# %%
results['address']['neighbourhood']
# Out:
# 'Long Island City'

# %% [markdown]
# Now we extract the neighborhood data from every crime and add it into a new data frame. This takes a very long time

# %%
crime_neighborhoods = []
for x in range(len(crime_data['Crime_Latitude'])):
    crime_lat = crime_data['Crime_Latitude'][x]
    crime_long = crime_data['Crime_Longitude'][x]
    url = f'https://us1.locationiq.com/v1/reverse.php?key={access_token}&lat={crime_lat}&lon={crime_long}&format=json'
    results = requests.get(url).json()
    try:
        crime_neighborhoods.append(results['address']['neighbourhood'])
        print(results['address']['neighbourhood'])
    except:
        crime_neighborhoods.append(np.nan)
        print(np.nan)
# Out:
# Long Island City
# Long Island City
# Westchester Square
# Flushing
# Morris Heights
# Melrose
# Richmond Hill
# Chelsea
# Mott Haven
# Rockaway Park
# Bedford-Stuyvesant
# Richmond Hill
# Flatbush
# Port Richmond
# nan
# East New York
# Astoria
# Jamaica
# Bedford-Stuyvesant
# Parkchester
# Mott Haven
# Flatbush
# Tribeca
# Ridgewood
# Midtown West
# St. George
# Ridgewood
# Sheepshead Bay
# Washington Heights
# Mott Haven
# North Corona
# Soundview Bruckner
# Mott Haven
# Kensington
# Forest Hills
# Forest Hills
# Astoria
# East Morrisania
# East New York
# Flatbush
# Morris Heights
# Fort Greene
# Fordham
# East Elmhurst
# Stuyvesant Town
# Astoria
# Prospect-Lefferts Gardens
# Prospect-Lefferts Gardens
# Mill Basin
# Williamsburg
# Richmond Hill
# St. George
# Midtown West
# Bushwick
# East Village
# Bushwick
# Brownsville
# Fresh Meadows
# East New York
# Rockaway Beach
# Rockaway Beach
# Forest Hills
# Bedford-Stuyvesant
# Midtown West
# Bedford-Stuyvesant
# Midtown East
# Gramercy
# Allerton
# Allerton
# Allerton
# Allerton
# Allerton
# Two Bridges
# Throgs Neck
# Flatbush
# Richmond Hill
# Maspeth
# Midtown West
# Bayswater
# East Flatbush
# East Flatbush
# Upper East Side
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Flatiron District
# Chelsea
# Civic Center
# Richmond Hill
# Maspeth
# Richmond Hill
# Hell's Kitchen
# Upper East Side
# Hell's Kitchen
# Kingsbridge
# Williamsburg
# Westchester Square
# East Harlem
# Jamaica
# Claremont
# Crown Heights
# Mott Haven
# Sunset Park
# Sunset Park
# College Point
# Arverne
# Sunset Park
# Mott Haven
# Ozone Park
# NoHo
# NoHo
# Morrisania
# West Village
# Washington Heights
# Borough Park
# Wakefield
# Brookville
# Port Morris
# Port Morris
# East Morrisania
# Civic Center
# Soundview Bruckner
# Upper East Side
# Corona
# Corona
# Chelsea
# Brownsville
# Elmhurst
# Central Harlem
# Fordham
# Bull's Head
# Marble Hill
# Hollis
# Jamaica
# Richmond Hill
# Kips Bay
# East New York
# Mount Hope
# Coop City
# East Flatbush
# Central Harlem
# East New York
# Baychester
# Greenwich Village
# Fordham
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Highbridge
# Midtown West
# Crown Heights
# Mount Hope
# Chelsea
# Randall's Island
# Corona
# Midtown West
# Flatiron District
# Flushing
# Longwood
# Flushing
# Bedford-Stuyvesant
# Flushing
# Elmhurst
# Fordham
# Parkchester
# Brookville
# West Village
# College Point
# Bedford-Stuyvesant
# Greenwich Village
# Bayswater
# Downtown Brooklyn
# Washington Heights
# Allerton
# Midtown West
# Tribeca
# Bedford-Stuyvesant
# Coney Island
# Midtown West
# Crown Heights
# Richmond Hill
# Claremont
# Parkchester
# Upper West Side
# Laurelton
# Morrisania
# Bedford-Stuyvesant
# Midtown East
# East Harlem
# Upper East Side
# Bushwick
# Inwood
# Wakefield
# Chelsea
# Bensonhurst
# West Farms
# Midtown West
# University Heights
# East Elmhurst
# Williamsburg
# Upper West Side
# Midtown West
# Upper West Side
# Fort Greene
# Brownsville
# Bath Beach
# Flatbush
# Flushing
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Astoria
# Morrisania
# Pelham Gardens
# East Harlem
# Flatlands
# Mariners Harbor
# Huguenot
# Fordham
# Downtown Brooklyn
# Fort Greene
# Van Nest
# Olinville
# Crown Heights
# Wakefield
# Ozone Park
# East Harlem
# Arrochar
# Flushing
# Williamsbridge
# Clinton Hill
# Forest Hills
# Rockaway Beach
# Red Hook
# Hamilton Heights
# Canarsie
# Williamsburg
# Bensonhurst
# Central Harlem
# Hell's Kitchen
# Hell's Kitchen
# Flatbush
# Flatbush
# Concourse
# Upper West Side
# Laurelton
# Jackson Heights
# Fordham
# Flatbush
# DUMBO
# Bedford-Stuyvesant
# Canarsie
# Midtown West
# Bensonhurst
# Woodside
# Brooklyn Heights
# East Flatbush
# Inwood
# Edenwald
# Upper West Side
# Bensonhurst
# Van Nest
# Claremont
# Norwood
# Brookville
# East Harlem
# Gravesend
# East New York
# Bedford-Stuyvesant
# East New York
# Kingsbridge
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# East Flatbush
# East Harlem
# Far Rockaway
# Jamaica
# Jamaica
# Mount Eden
# Clason Point
# Crown Heights
# Belmont
# East Morrisania
# Williamsbridge
# Sunset Park
# Washington Heights
# Mount Hope
# Bushwick
# Flatbush
# Mott Haven
# Bushwick
# Midtown West
# Flushing
# Mount Hope
# Fort Hamilton
# Park Slope
# South Ozone Park
# Astoria
# Astoria
# Brownsville
# Morrisania
# Grant City
# Soundview Bruckner
# St. George
# Flushing
# Flushing
# East Flatbush
# Parkchester
# Fort Greene
# Prospect-Lefferts Gardens
# Randall Manor
# Allerton
# Rockaway Beach
# Washington Heights
# Washington Heights
# Gravesend
# Bayridge
# Belmont
# Hell's Kitchen
# Gravesend
# Rockaway Park
# Concourse Village
# Prince's Bay
# Maspeth
# Prince's Bay
# Edenwald
# Rego Park
# Prospect Heights
# Midtown West
# Sunset Park
# Sunset Park
# Huguenot
# Clinton Hill
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Mott Haven
# Gravesend
# Central Harlem
# Two Bridges
# Morningside Heights
# East Harlem
# Central Harlem
# Highbridge
# Bronxdale
# Chelsea
# Park Slope
# Jamaica
# Jamaica
# Upper West Side
# Midtown East
# Soundview Bruckner
# Bensonhurst
# Pelham Gardens
# Hollis
# Highbridge
# Borough Park
# Richmond Hill
# Upper West Side
# Longwood
# Prospect-Lefferts Gardens
# Maspeth
# Belmont
# East New York
# West Village
# Gravesend
# Soundview Bruckner
# Williamsburg
# Flushing
# Greenwich Village
# Mott Haven
# North Corona
# Bath Beach
# Longwood
# Mount Eden
# Arverne
# Little Italy
# Central Harlem
# Morris Heights
# Washington Heights
# Crown Heights
# Bedford-Stuyvesant
# Bedford-Stuyvesant
# Allerton
# Jamaica
# Washington Heights
# Midtown West
# East Flatbush
# East New York
# Olinville
# Bushwick
# Crown Heights
# Ridgewood
# Cypress Hills
# Ozone Park
# Concourse
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Elmhurst
# Fordham
# Brownsville
# Throgs Neck
# Bushwick
# Gowanus Heights
# Central Harlem
# Crown Heights
# Central Harlem
# East Elmhurst
# East Elmhurst
# Brownsville
# New Dorp
# Flatbush
# East Elmhurst
# Hamilton Heights
# Long Island City
# Long Island City
# Bayside
# Melrose
# Belmont
# Longwood
# Prospect Heights
# Midtown West
# Sunset Park
# East Flatbush
# Brownsville
# Midland Beach
# Laurelton
# East New York
# Lower East Side
# Throgs Neck
# Fort Greene
# Rockaway Beach
# Central Harlem
# Bushwick
# Astoria
# Washington Heights
# New Dorp
# Richmond Hill
# Cypress Hills
# Kingsbridge
# Midtown West
# Washington Heights
# Bushwick
# Lower East Side
# Clason Point
# Midtown West
# Murray Hill
# Little Italy
# Lower East Side
# Concourse Village
# Central Harlem
# Stapleton
# Midtown West
# Fordham
# Gramercy
# East Harlem
# Fordham
# Mott Haven
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Bushwick
# Mount Eden
# Williamsburg
# South Ozone Park
# East New York
# Morningside Heights
# Claremont
# Washington Heights
# Gravesend
# Flushing
# East New York
# Upper West Side
# Lower East Side
# Kips Bay
# Lower East Side
# Lower East Side
# Inwood
# Parkchester
# Mott Haven
# Fordham
# Mount Eden
# Forest Hills
# Wakefield
# Mount Eden
# Two Bridges
# East Harlem
# Jamaica
# Flatiron District
# Red Hook
# Pelham Gardens
# Washington Heights
# Washington Heights
# Highbridge
# Bensonhurst
# Lower East Side
# Lower East Side
# Fordham
# Corona
# Astoria
# Williamsburg
# Sunset Park
# Far Rockaway
# Central Harlem
# Brighton Beach
# Chelsea
# Borough Park
# Flushing
# Flushing
# Norwood
# Midtown West
# Olinville
# Brownsville
# Laurelton
# Mount Hope
# Hamilton Heights
# Soundview Bruckner
# Longwood
# Parkchester
# Morningside Heights
# East Flatbush
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Far Rockaway
# East New York
# East Village
# St. Albans
# Upper East Side
# Bushwick
# Midtown West
# East Village
# Elmhurst
# Jamaica
# Bayridge
# Mott Haven
# Allerton
# Claremont
# Castle Hill
# Brownsville
# Shore Acres
# Corona
# Mount Hope
# East Harlem
# East New York
# Upper East Side
# Flatbush
# West Village
# West Village
# Throgs Neck
# Clifton
# Lower East Side
# Bushwick
# Jamaica
# Crown Heights
# Longwood
# Kingsbridge
# Sheepshead Bay
# Middle Village
# East Harlem
# Flushing
# Arrochar
# Morris Heights
# Bedford-Stuyvesant
# Mount Hope
# Washington Heights
# Kingsbridge
# Prospect Heights
# Long Island City
# Maspeth
# Financial District
# Maspeth
# Central Harlem
# Morrisania
# East New York
# Clinton Hill
# Claremont
# Bedford-Stuyvesant
# Upper West Side
# Upper West Side
# Upper West Side
# Upper West Side
# Upper West Side
# Upper West Side
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# East New York
# Kingsbridge
# East Village
# Upper East Side
# Country Club
# Inwood
# Highbridge
# Long Island City
# East Flatbush
# Upper East Side
# East Harlem
# Williamsbridge
# Bayridge
# Fordham
# Morris Heights
# Gramercy
# Hamilton Heights
# Bushwick
# East Harlem
# City Island
# Fordham
# Elmhurst
# East Harlem
# Morris Heights
# Upper West Side
# Bronxdale
# East Harlem
# Bayridge
# Washington Heights
# Fordham
# Upper East Side
# Kingsbridge
# Bushwick
# Ridgewood
# Upper East Side
# Graniteville
# East Elmhurst
# Hamilton Heights
# Edenwald
# Crown Heights
# Longwood
# Hamilton Heights
# Kingsbridge
# Forest Hills
# Van Nest
# Tompkinsville
# Kensington
# Whitestone
# Kingsbridge
# Kingsbridge
# Elmhurst
# St. Albans
# Bushwick
# East Flatbush
# Central Harlem
# Brownsville
# Forest Hills
# Fordham
# Bedford-Stuyvesant
# South Ozone Park
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Midtown West
# Central Harlem
# Borough Park
# Bedford-Stuyvesant
# Chelsea
# Midtown West
# Forest Hills
# Jackson Heights
# Kingsbridge
# Cypress Hills
# Gramercy
# Norwood
# Bayridge
# Gravesend
# Chelsea
# Nolita
# Central Harlem
# Kensington
# Allerton
# Prospect-Lefferts Gardens
# Throgs Neck
# Central Harlem
# Glendale
# Morris Park
# Chelsea
# Longwood
# East New York
# Williamsburg
# Williamsburg
# Forest Hills
# Longwood
# East Harlem
# Wakefield
# Astoria
# Central Harlem
# Bedford-Stuyvesant
# Hamilton Heights
# Stuyvesant Town
# Greenpoint
# SoHo
# Flushing
# Greenpoint
# East Village
# South Ozone Park
# Richmond Hill
# Flatbush
# Midtown West
# Ridgewood
# East Elmhurst
# Longwood
# Brownsville
# Queens Village
# Forest Hills
# Fordham
# Upper East Side
# Greenwich Village
# Gravesend
# Upper West Side
# East Village
# Flatlands
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
crime_data['Crime_Neighborhood'] = crime_neighborhoods
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Lets drop missing values

# %%
crime_data.dropna(axis = 0, inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Lets group the crime activity by neighborhood

# %%
CNYN = crime_data.groupby(['Crime_Neighborhood']).count()

# %%
CNYN.reset_index(inplace = True)
CNYN.rename({'Crime_Neighborhood' : 'Neighborhood', 'Crime_Borough' : 'Num_of_Crimes'}, axis = 1, inplace = True)
CNYN = CNYN[['Neighborhood', 'Num_of_Crimes']]

# %%
CNYN
# Out:
#            Neighborhood  Num_of_Crimes
# 0              Allerton             10
# 1              Arrochar              2
# 2               Arverne              2
# 3               Astoria              9
# 4            Bath Beach              2
# 5            Baychester              1
# 6              Bayridge              5
# 7               Bayside              1
# 8             Bayswater              2
# 9    Bedford-Stuyvesant             17
# 10              Belmont              4
# 11          Bensonhurst              6
# 12         Borough Park              4
# 13       Brighton Beach              1
# 14            Bronxdale              2
# 15     Brooklyn Heights              1
# 16           Brookville              3
# 17          Brownsville             11
# 18          Bull's Head              1
# 19             Bushwick             15
# 20             Canarsie              2
# 21          Castle Hill              1
# 22       Central Harlem             17
# 23              Chelsea             10
# 24          City Island              1
# 25         Civic Center              2
# 26            Claremont              6
# 27         Clason Point              2
# 28              Clifton              1
# 29         Clinton Hill              3
# ..                  ...            ...
# 122           Ridgewood              5
# 123      Rockaway Beach              5
# 124       Rockaway Park              2
# 125      Sheepshead Bay              2
# 126         Shore Acres              1
# 127                SoHo              1
# 128  Soundview Bruckner              6
# 129    South Ozone Park              4
# 130          St. Albans              2
# 131          St. George              3
# 132           Stapleton              1
# 133     Stuyvesant Town              2
# 134         Sunset Park              8
# 135         Throgs Neck              5
# 136       Tompkinsville              1
# 137             Tribeca              2
# 138         Two Bridges              3
# 139  University Heights              1
# 140     Upper East Side             11
# 141     Upper West Side             16
# 142            Van Nest              3
# 143           Wakefield              5
# 144  Washington Heights             15
# 145          West Farms              1
# 146        West Village              5
# 147  Westchester Square              2
# 148          Whitestone              1
# 149      Williamsbridge              3
# 150        Williamsburg              9
# 151            Woodside              1
#
# [152 rows x 2 columns]

# %%
print(CNYN.shape)
print(CNYN['Num_of_Crimes'].sum())
# Out:
# (152, 2)
# 681

# %% [markdown]
# So we have 712 crimes representing 157 neighborhoods
#
# Lets move on to the next dataset which is the apartment rental cost. This dataset will have to be scraped from a website using beautifulsoup

# %%
# Making two lists that will house the neighborhood names and rent cost in queens
qnbhd = []
qrent = []
# Getting the html from the web
qsource = requests.get('https://www.rentcafe.com/average-rent-market-trends/us/ny/queens/').text
qsoup = BeautifulSoup(qsource, 'lxml')
qsoup = qsoup.find(id = 'MarketTrendsAverageRentTable')
print(qsoup.prettify())
for i in qsoup.find('tbody').find_all(class_ = 'current-row'):
    print(i.th)
    print(i.td)
    qnbhd.append(i.th.text)
    qrent.append(i.td.text[1:])
# Out:
# <table class="market-trends" id="MarketTrendsAverageRentTable">
#  <thead>
#   <tr>
#    <th class="average-rent" colspan="6">
#     Average Rent
#    </th>
#   </tr>
#  </thead>
#  <tbody>
#   <tr>
#    <th>
#     Neighborhood
#    </th>
#    <th>
#     Average Rent
#    </th>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Hollis
#    </th>
#    <td>
#     $1,037
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     South Astoria
#    </th>
#    <td>
#     $1,550
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Jamaica Estates
#    </th>
#    <td>
#     $1,712
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Murray Hill
#    </th>
#    <td>
#     $1,719
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     College Point
#    </th>
#    <td>
#     $1,719
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Auburndale
#    </th>
#    <td>
#     $1,750
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Pomonok
#    </th>
#    <td>
#     $1,766
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Jamaica Hills
#    </th>
#    <td>
#     $1,766
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Fresh Meadows
#    </th>
#    <td>
#     $1,766
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Jamaica
#    </th>
#    <td>
#     $1,773
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Briarwood
#    </th>
#    <td>
#     $1,773
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Downtown Flushing
#    </th>
#    <td>
#     $1,807
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Bellerose
#    </th>
#    <td>
#     $1,861
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Queensboro Hill
#    </th>
#    <td>
#     $1,875
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     East Flushing
#    </th>
#    <td>
#     $1,875
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Little Neck
#    </th>
#    <td>
#     $1,891
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Douglaston
#    </th>
#    <td>
#     $1,891
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Corona Park
#    </th>
#    <td>
#     $1,917
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Corona
#    </th>
#    <td>
#     $1,917
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Elmhurst
#    </th>
#    <td>
#     $1,922
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     East Elmhurst
#    </th>
#    <td>
#     $1,936
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Woodside
#    </th>
#    <td>
#     $1,950
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Sunnyside Gardens
#    </th>
#    <td>
#     $1,950
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Maspeth
#    </th>
#    <td>
#     $1,950
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Rego Park
#    </th>
#    <td>
#     $2,110
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Queens Village
#    </th>
#    <td>
#     $2,160
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Far Rockaway
#    </th>
#    <td>
#     $2,162
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Jackson Heights
#    </th>
#    <td>
#     $2,222
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Old Astoria
#    </th>
#    <td>
#     $2,452
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Ditmars - Steinway
#    </th>
#    <td>
#     $2,452
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Forest Hills
#    </th>
#    <td>
#     $2,558
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Sunnyside
#    </th>
#    <td>
#     $3,248
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     Hunters Point
#    </th>
#    <td>
#     $3,466
#    </td>
#   </tr>
#   <tr class="current-row">
#    <th>
#     LIC
#    </th>
#    <td>
#     $3,488
#    </td>
#   </tr>
#  </tbody>
# </table>
#
# <th>Hollis</th>
# <td>$1,037</td>
# <th>South Astoria</th>
# <td>$1,550</td>
# <th>Jamaica Estates</th>
# <td>$1,712</td>
# <th>Murray Hill</th>
# <td>$1,719</td>
# <th>College Point</th>
# <td>$1,719</td>
# <th>Auburndale</th>
# <td>$1,750</td>
# <th>Pomonok</th>
# <td>$1,766</td>
# <th>Jamaica Hills</th>
# <td>$1,766</td>
# <th>Fresh Meadows</th>
# <td>$1,766</td>
# <th>Jamaica</th>
# <td>$1,773</td>
# <th>Briarwood</th>
# <td>$1,773</td>
# <th>Downtown Flushing</th>
# <td>$1,807</td>
# <th>Bellerose</th>
# <td>$1,861</td>
# <th>Queensboro Hill</th>
# <td>$1,875</td>
# <th>East Flushing</th>
# <td>$1,875</td>
# <th>Little Neck</th>
# <td>$1,891</td>
# <th>Douglaston</th>
# <td>$1,891</td>
# <th>Corona Park</th>
# <td>$1,917</td>
# <th>Corona</th>
# <td>$1,917</td>
# <th>Elmhurst</th>
# <td>$1,922</td>
# <th>East Elmhurst</th>
# <td>$1,936</td>
# <th>Woodside</th>
# <td>$1,950</td>
# <th>Sunnyside Gardens</th>
# <td>$1,950</td>
# <th>Maspeth</th>
# <td>$1,950</td>
# <th>Rego Park</th>
# <td>$2,110</td>
# <th>Queens Village</th>
# <td>$2,160</td>
# <th>Far Rockaway</th>
# <td>$2,162</td>
# <th>Jackson Heights</th>
# <td>$2,222</td>
# <th>Old Astoria</th>
# <td>$2,452</td>
# <th>Ditmars - Steinway</th>
# <td>$2,452</td>
# <th>Forest Hills</th>
# <td>$2,558</td>
# <th>Sunnyside</th>
# <td>$3,248</td>
# <th>Hunters Point</th>
# <td>$3,466</td>
# <th>LIC</th>
# <td>$3,488</td>

# %%
# Making the dataframe
q_nbhds_rent = pd.DataFrame()

# Adding neighborhood names and rent to the dataframe
q_nbhds_rent['Neighborhood'] = qnbhd
# Removing the commas from the rent and converting to integer
q_nbhds_rent['Rent'] = list(map(lambda x: int(x.replace(',', '')) ,qrent))
q_nbhds_rent
# Out:
#           Neighborhood  Rent
# 0               Hollis  1037
# 1        South Astoria  1550
# 2      Jamaica Estates  1712
# 3          Murray Hill  1719
# 4        College Point  1719
# 5           Auburndale  1750
# 6              Pomonok  1766
# 7        Jamaica Hills  1766
# 8        Fresh Meadows  1766
# 9              Jamaica  1773
# 10           Briarwood  1773
# 11   Downtown Flushing  1807
# 12           Bellerose  1861
# 13     Queensboro Hill  1875
# 14       East Flushing  1875
# 15         Little Neck  1891
# 16          Douglaston  1891
# 17         Corona Park  1917
# 18              Corona  1917
# 19            Elmhurst  1922
# 20       East Elmhurst  1936
# 21            Woodside  1950
# 22   Sunnyside Gardens  1950
# 23             Maspeth  1950
# 24           Rego Park  2110
# 25      Queens Village  2160
# 26        Far Rockaway  2162
# 27     Jackson Heights  2222
# 28         Old Astoria  2452
# 29  Ditmars - Steinway  2452
# 30        Forest Hills  2558
# 31           Sunnyside  3248
# 32       Hunters Point  3466
# 33                 LIC  3488

# %% [markdown]
# Now we are done with the data for the queens neighborhoods.
# Let us repeat the process with Brooklyn, Bronx, and Manhattan

# %%
# Making two lists that will house the neighborhood names and rent cost in Brooklyn
brooknbhd = []
brookrent = []
# Getting the html from the web
brooksource = requests.get('https://www.rentcafe.com/average-rent-market-trends/us/ny/brooklyn/').text
brooksoup = BeautifulSoup(brooksource, 'lxml')
brooksoup = brooksoup.find(id = 'MarketTrendsAverageRentTable')

for i in brooksoup.find('tbody').find_all(class_ = 'current-row'):
    brooknbhd.append(i.th.text)
    brookrent.append(i.td.text[1:])
    
# Making the dataframe
brook_nbhds_rent = pd.DataFrame()

# Adding neighborhood names and rent to the dataframe
brook_nbhds_rent['Neighborhood'] = brooknbhd
# Removing the commas from the rent and converting to integer
brook_nbhds_rent['Rent'] = list(map(lambda x: int(x.replace(',', '')) ,brookrent))
brook_nbhds_rent
# Out:
#                            Neighborhood  Rent
# 0                             Flatlands  1492
# 1                           Marine Park  1659
# 2                               Madison  1659
# 3                       Gerritsen Beach  1659
# 4                             Homecrest  1717
# 5                           Bensonhurst  1795
# 6                            Bath Beach  1795
# 7                               Midwood  1825
# 8                         Fiske Terrace  1825
# 9                            Kensington  1839
# 10                            Gravesend  1840
# 11                        Crown Heights  1853
# 12                         Borough Park  1898
# 13                          Ditmas Park  1944
# 14                  Prospect Park South  1997
# 15          Prospect - Lefferts Gardens  2009
# 16                             Flatbush  2009
# 17                              Wingate  2114
# 18                       Sheepshead Bay  2131
# 19                        East Flatbush  2178
# 20                             Canarsie  2178
# 21                      Manhattan Beach  2214
# 22                       Brighton Beach  2214
# 23                      Windsor Terrace  2361
# 24                         Clinton Hill  2671
# 25                   Bedford-Stuyvesant  2784
# 26                        Prospect Park  2876
# 27                             Red Hook  2916
# 28                      Carroll Gardens  2916
# 29                             Bushwick  3065
# 30                   Brooklyn Navy Yard  3136
# 31                              Gowanus  3247
# 32                         Williamsburg  3247
# 33                     Prospect Heights  3373
# 34  Columbia Street Waterfront District  3401
# 35                          Cobble Hill  3401
# 36                          Fort Greene  3403
# 37                         Vinegar Hill  3456
# 38                                DUMBO  3456
# 39                    Downtown Brooklyn  3456
# 40                     Brooklyn Heights  3456
# 41                          Boerum Hill  3462
# 42                           Park Slope  3513
# 43                    Greenwood Heights  3538

# %%
# Making two lists that will house the neighborhood names and rent cost in Bronx
bronxnbhd = []
bronxrent = []
# Getting the html from the web
bronxsource = requests.get('https://www.rentcafe.com/average-rent-market-trends/us/ny/bronx/').text
bronxsoup = BeautifulSoup(bronxsource, 'lxml')
bronxsoup = bronxsoup.find(id = 'MarketTrendsAverageRentTable')

for i in bronxsoup.find('tbody').find_all(class_ = 'current-row'):
    bronxnbhd.append(i.th.text)
    bronxrent.append(i.td.text[1:])
    
# Making the dataframe
bronx_nbhds_rent = pd.DataFrame()

# Adding neighborhood names and rent to the dataframe
bronx_nbhds_rent['Neighborhood'] = bronxnbhd
# Removing the commas from the rent and converting to integer
bronx_nbhds_rent['Rent'] = list(map(lambda x: int(x.replace(',', '')) ,bronxrent))
bronx_nbhds_rent
# Out:
#                         Neighborhood  Rent
# 0                     Spuyten Duyvil  1694
# 1                          Riverdale  1694
# 2  Kingsbridge Heights - Jerome Park  1694
# 3                        Kingsbridge  1694

# %%
# Making two lists that will house the neighborhood names and rent cost in Manhattan
mnbhd = []
mrent = []
# Getting the html from the web
msource = requests.get('https://www.rentcafe.com/average-rent-market-trends/us/ny/manhattan/').text
msoup = BeautifulSoup(msource, 'lxml')
msoup = msoup.find(id = 'MarketTrendsAverageRentTable')

for i in msoup.find('tbody').find_all(class_ = 'current-row'):
    mnbhd.append(i.th.text)
    mrent.append(i.td.text[1:])
    
# Making the dataframe
m_nbhds_rent = pd.DataFrame()

# Adding neighborhood names and rent to the dataframe
m_nbhds_rent['Neighborhood'] = mnbhd
# Removing the commas from the rent and converting to integer
m_nbhds_rent['Rent'] = list(map(lambda x: int(x.replace(',', '')) ,mrent))
m_nbhds_rent
# Out:
#                        Neighborhood  Rent
# 0                       Marble Hill  1694
# 1                            Inwood  2225
# 2                Washington Heights  2243
# 3        Randalls and Wards Islands  2336
# 4                       East Harlem  3334
# 5                        Tudor City  3338
# 6                  Roosevelt Island  3427
# 7                            Harlem  3604
# 8                    Liberty Island  3718
# 9                  Governors Island  3718
# 10                     Ellis Island  3718
# 11                  Stuyvesant Town  3720
# 12               Central Park South  3786
# 13  Theatre District - Times Square  3897
# 14                  Central Midtown  3913
# 15                       Turtle Bay  3973
# 16         Clinton - Hell's Kitchen  3991
# 17               Financial District  4005
# 18                      Murray Hill  4022
# 19                         Kips Bay  4089
# 20                     Sutton Place  4135
# 21             Peter Cooper Village  4150
# 22                            NoMad  4156
# 23                     Civic Center  4241
# 24                    Gramercy Park  4261
# 25                        Yorkville  4271
# 26                    Carnegie Hill  4271
# 27                     Hudson Yards  4302
# 28              Morningside Heights  4314
# 29                      Two Bridges  4322
# 30                Flatiron District  4328
# 31                       Lenox Hill  4332
# 32                     East Village  4334
# 33                             NoHo  4335
# 34                          Chelsea  4359
# 35                        Koreatown  4368
# 36                 Garment District  4368
# 37                Greenwich Village  4415
# 38                             SoHo  4485
# 39                           NoLIta  4485
# 40             Meatpacking District  4500
# 41                  Lower East Side  4516
# 42                     West Village  4524
# 43                 Manhattan Valley  4578
# 44                        Chinatown  4609
# 45                    Hudson Square  4640
# 46                  Upper West Side  4654
# 47                   Lincoln Square  4706
# 48                          TriBeCa  4845
# 49                     Little Italy  4845
# 50                Battery Park City  5603

# %% [markdown]
# We will now join the four dataframes together

# %%
NYCRENT = pd.concat([q_nbhds_rent, brook_nbhds_rent, bronx_nbhds_rent, m_nbhds_rent], axis = 0)

# %%
NYCRENT.reset_index(inplace = True)

# %%
NYCRENT.drop(['index'],axis = 1, inplace = True)
NYCRENT
# Out:
#              Neighborhood  Rent
# 0                  Hollis  1037
# 1           South Astoria  1550
# 2         Jamaica Estates  1712
# 3             Murray Hill  1719
# 4           College Point  1719
# 5              Auburndale  1750
# 6                 Pomonok  1766
# 7           Jamaica Hills  1766
# 8           Fresh Meadows  1766
# 9                 Jamaica  1773
# 10              Briarwood  1773
# 11      Downtown Flushing  1807
# 12              Bellerose  1861
# 13        Queensboro Hill  1875
# 14          East Flushing  1875
# 15            Little Neck  1891
# 16             Douglaston  1891
# 17            Corona Park  1917
# 18                 Corona  1917
# 19               Elmhurst  1922
# 20          East Elmhurst  1936
# 21               Woodside  1950
# 22      Sunnyside Gardens  1950
# 23                Maspeth  1950
# 24              Rego Park  2110
# 25         Queens Village  2160
# 26           Far Rockaway  2162
# 27        Jackson Heights  2222
# 28            Old Astoria  2452
# 29     Ditmars - Steinway  2452
# ..                    ...   ...
# 103  Peter Cooper Village  4150
# 104                 NoMad  4156
# 105          Civic Center  4241
# 106         Gramercy Park  4261
# 107             Yorkville  4271
# 108         Carnegie Hill  4271
# 109          Hudson Yards  4302
# 110   Morningside Heights  4314
# 111           Two Bridges  4322
# 112     Flatiron District  4328
# 113            Lenox Hill  4332
# 114          East Village  4334
# 115                  NoHo  4335
# 116               Chelsea  4359
# 117             Koreatown  4368
# 118      Garment District  4368
# 119     Greenwich Village  4415
# 120                  SoHo  4485
# 121                NoLIta  4485
# 122  Meatpacking District  4500
# 123       Lower East Side  4516
# 124          West Village  4524
# 125      Manhattan Valley  4578
# 126             Chinatown  4609
# 127         Hudson Square  4640
# 128       Upper West Side  4654
# 129        Lincoln Square  4706
# 130               TriBeCa  4845
# 131          Little Italy  4845
# 132     Battery Park City  5603
#
# [133 rows x 2 columns]

# %% [markdown]
# The NYCRENT dataframe includes 133 neighbor hoods with their average rent.

# %% [markdown]
# # Merging the data sets
# When we merge the data sets we will remove all the neighborhoods that dont have a value for average rent

# %%
# The data sets that we will merge. Renamingthem for clarity
NYCRENT

NYCCRIMES = CNYN

NYCNBHDS = NYNB

# We will create the venue data set when we know exactly which neigborhoods are in the final data sets

# %% [markdown]
# Lets make a data frame with the rent and crime neighborhoods

# %%
NYC = pd.merge(NYCRENT, NYCCRIMES, on = 'Neighborhood')

# %% [markdown]
# Now we join the data frame that we just created with the neighborhood data

# %%
NYC = pd.merge(NYC, NYCNBHDS, on = 'Neighborhood')
NYC
# Out:
#            Neighborhood  Rent  Num_of_Crimes        Borough   Latitude  \
# 0                Hollis  1037              2         Queens  40.711243
# 1           Murray Hill  1719              1      Manhattan  40.748303
# 2           Murray Hill  1719              1         Queens  40.764126
# 3           Murray Hill  4022              1      Manhattan  40.748303
# 4           Murray Hill  4022              1         Queens  40.764126
# 5         College Point  1719              2         Queens  40.784903
# 6         Fresh Meadows  1766              1         Queens  40.734394
# 7                Corona  1917              5         Queens  40.742382
# 8              Elmhurst  1922              6         Queens  40.744049
# 9         East Elmhurst  1936              7         Queens  40.764073
# 10             Woodside  1950              1         Queens  40.746349
# 11              Maspeth  1950              6         Queens  40.725427
# 12            Rego Park  2110              1         Queens  40.728974
# 13       Queens Village  2160              1         Queens  40.718893
# 14         Far Rockaway  2162              3         Queens  40.603134
# 15      Jackson Heights  2222              2         Queens  40.751981
# 16         Forest Hills  2558             10         Queens  40.725264
# 17            Flatlands  1492              2       Brooklyn  40.630446
# 18          Bensonhurst  1795              6       Brooklyn  40.611009
# 19           Bath Beach  1795              2       Brooklyn  40.599519
# 20           Kensington  1839              3       Brooklyn  40.642382
# 21            Gravesend  1840              8       Brooklyn  40.595260
# 22        Crown Heights  1853             10       Brooklyn  40.670829
# 23         Borough Park  1898              4       Brooklyn  40.633131
# 24             Flatbush  2009             12       Brooklyn  40.636326
# 25       Sheepshead Bay  2131              2       Brooklyn  40.586890
# 26        East Flatbush  2178             11       Brooklyn  40.641718
# 27             Canarsie  2178              2       Brooklyn  40.635564
# 28       Brighton Beach  2214              1       Brooklyn  40.576825
# 29         Clinton Hill  2671              3       Brooklyn  40.693229
# 30             Red Hook  2916              2       Brooklyn  40.676253
# 31             Bushwick  3065             15       Brooklyn  40.698116
# 32         Williamsburg  3247              9       Brooklyn  40.707144
# 33     Prospect Heights  3373              3       Brooklyn  40.676822
# 34          Fort Greene  3403              5       Brooklyn  40.688527
# 35     Brooklyn Heights  3456              1       Brooklyn  40.695864
# 36           Park Slope  3513              2       Brooklyn  40.672321
# 37          Kingsbridge  1694             11          Bronx  40.881687
# 38          Marble Hill  1694              1      Manhattan  40.876551
# 39               Inwood  2225              4      Manhattan  40.867684
# 40   Washington Heights  2243             15      Manhattan  40.851903
# 41          East Harlem  3334             16      Manhattan  40.792249
# 42      Stuyvesant Town  3720              2      Manhattan  40.731000
# 43   Financial District  4005              1      Manhattan  40.707107
# 44         Civic Center  4241              2      Manhattan  40.715229
# 45  Morningside Heights  4314              3      Manhattan  40.808000
# 46         East Village  4334              6      Manhattan  40.727847
# 47              Chelsea  4359             10      Manhattan  40.744035
# 48              Chelsea  4359             10  Staten Island  40.594726
# 49    Greenwich Village  4415              4      Manhattan  40.726933
# 50      Lower East Side  4516              9      Manhattan  40.717807
# 51         West Village  4524              5      Manhattan  40.734434
# 52      Upper West Side  4654             16      Manhattan  40.787658
# 53         Little Italy  4845              2      Manhattan  40.719324
#
#     Longitude
# 0  -73.759250
# 1  -73.978332
# 2  -73.812763
# 3  -73.978332
# 4  -73.812763
# 5  -73.843045
# 6  -73.782713
# 7  -73.856825
# 8  -73.881656
# 9  -73.867041
# 10 -73.901842
# 11 -73.896217
# 12 -73.857827
# 13 -73.738715
# 14 -73.754980
# 15 -73.882821
# 16 -73.844475
# 17 -73.929113
# 18 -73.995180
# 19 -73.998752
# 20 -73.980421
# 21 -73.973471
# 22 -73.943291
# 23 -73.990498
# 24 -73.958401
# 25 -73.943186
# 26 -73.936103
# 27 -73.902093
# 28 -73.965094
# 29 -73.967843
# 30 -74.012759
# 31 -73.925258
# 32 -73.958115
# 33 -73.964859
# 34 -73.972906
# 35 -73.993782
# 36 -73.977050
# 37 -73.902818
# 38 -73.910660
# 39 -73.921210
# 40 -73.936900
# 41 -73.944182
# 42 -73.974052
# 43 -74.010665
# 44 -74.005415
# 45 -73.963896
# 46 -73.982226
# 47 -74.003116
# 48 -74.189560
# 49 -73.999914
# 50 -73.980890
# 51 -74.006180
# 52 -73.977059
# 53 -73.997305

# %% [markdown]
# Now that we know which neighborhoods to target we can now get the venue details for each neighborhood

# %%
NYCVENUES = getNearbyVenues(NYC['Neighborhood'], NYC['Latitude'], NYC['Longitude'])
NYCVENUES
# Out:
#       Neighborhood                                       Venue
# 0           Hollis                               Family Dollar
# 1           Hollis                                    T-Mobile
# 2           Hollis                                      SUBWAY
# 3           Hollis                                      Subway
# 4           Hollis                               Haggerty Park
# 5           Hollis                            Lion Paw Studios
# 6           Hollis                          CTown Supermarkets
# 7           Hollis                   Popeyes Louisiana Kitchen
# 8           Hollis                                  New Ho Wah
# 9           Hollis                           Avenue Z Desserts
# 10          Hollis                    Franhill Shopping Center
# 11          Hollis                                         KFC
# 12          Hollis                   Popeyes Louisiana Kitchen
# 13          Hollis                              Franhill Plaza
# 14          Hollis                                Jamaica Park
# 15     Murray Hill                              Ippodo Tea Co.
# 16     Murray Hill                                     Kajitsu
# 17     Murray Hill                             Sons of Thunder
# 18     Murray Hill                                   Perk Kafe
# 19     Murray Hill                                Pod 39 Hotel
# 20     Murray Hill                                    Franchia
# 21     Murray Hill                                   Dun Huang
# 22     Murray Hill                          Pod 39 Rooftop Bar
# 23     Murray Hill                               Bedford & Co.
# 24     Murray Hill                           The Renwick Hotel
# 25     Murray Hill                                 Shake Shack
# 26     Murray Hill                        Momosan Ramen & Sake
# 27     Murray Hill                                Little Alley
# 28     Murray Hill                 The Jazz Room at The Kitano
# 29     Murray Hill                 The Morgan Library & Museum
# ...            ...                                         ...
# 2835  Little Italy                                  Chikarashi
# 2836  Little Italy                                  Ramen Hood
# 2837  Little Italy                            MUJI 無印良品 (MUJI)
# 2838  Little Italy                             Bowery Ballroom
# 2839  Little Italy                         GoGreen Organic Spa
# 2840  Little Italy                               Fay Da Bakery
# 2841  Little Italy                                    Madewell
# 2842  Little Italy                   Mian Tian Sing Hair Salon
# 2843  Little Italy                              YogaWorks Soho
# 2844  Little Italy                                     Fig. 19
# 2845  Little Italy                                       Brodo
# 2846  Little Italy                                   Rintintin
# 2847  Little Italy                                 Kung Fu Tea
# 2848  Little Italy                            Lung Moon Bakery
# 2849  Little Italy                                      Canada
# 2850  Little Italy                     Elizabeth Street Garden
# 2851  Little Italy                                         CB2
# 2852  Little Italy                                     Cocoron
# 2853  Little Italy                           MoMA Design Store
# 2854  Little Italy                                    The Boil
# 2855  Little Italy                         Rubirosa Ristorante
# 2856  Little Italy                               Sacred Tattoo
# 2857  Little Italy                         Hotel 50 Bowery NYC
# 2858  Little Italy  McNally Jackson Store: Goods For The Study
# 2859  Little Italy                                     Peasant
# 2860  Little Italy                           Go Believe Bakery
# 2861  Little Italy                                Proper Cloth
# 2862  Little Italy                                   Balthazar
# 2863  Little Italy                              UFC NYC - SoHo
# 2864  Little Italy                                       Teado
#
# [2865 rows x 2 columns]

# %% [markdown]
# Now we will group the venues dataset by neighborhood and count the number of venues per neighborhood

# %%
NYCVENUES2 = NYCVENUES.groupby(['Neighborhood']).count()

# %%
NYCVENUES2
# Out:
#                      Venue
# Neighborhood
# Bath Beach              47
# Bensonhurst             37
# Borough Park            20
# Brighton Beach          42
# Brooklyn Heights       100
# Bushwick                76
# Canarsie                 6
# Chelsea                104
# Civic Center           100
# Clinton Hill            96
# College Point           41
# Corona                  17
# Crown Heights           20
# East Elmhurst           14
# East Flatbush           13
# East Harlem             44
# East Village           100
# Elmhurst                39
# Far Rockaway            35
# Financial District     100
# Flatbush                23
# Flatlands               21
# Forest Hills            39
# Fort Greene             80
# Fresh Meadows           15
# Gravesend               27
# Greenwich Village      100
# Hollis                  15
# Inwood                  58
# Jackson Heights         80
# Kensington              36
# Kingsbridge             71
# Little Italy           100
# Lower East Side         60
# Marble Hill             26
# Maspeth                 31
# Morningside Heights     40
# Murray Hill            290
# Park Slope              74
# Prospect Heights        79
# Queens Village          17
# Red Hook                48
# Rego Park               44
# Sheepshead Bay          27
# Stuyvesant Town         16
# Upper West Side        100
# Washington Heights      85
# West Village           100
# Williamsburg            32
# Woodside                80

# %% [markdown]
# We will use the amount of foursquare venues near a neighborhood as an indication of how popular it is

# %%
NYCVENUES = NYCVENUES2.rename({'Venue' : 'Num of Venues'}, axis = 1)

# %%
NYCVENUES.reset_index(inplace = True)

# %%
NYCVENUES
# Out:
#            Neighborhood  Num of Venues
# 0            Bath Beach             47
# 1           Bensonhurst             37
# 2          Borough Park             20
# 3        Brighton Beach             42
# 4      Brooklyn Heights            100
# 5              Bushwick             76
# 6              Canarsie              6
# 7               Chelsea            104
# 8          Civic Center            100
# 9          Clinton Hill             96
# 10        College Point             41
# 11               Corona             17
# 12        Crown Heights             20
# 13        East Elmhurst             14
# 14        East Flatbush             13
# 15          East Harlem             44
# 16         East Village            100
# 17             Elmhurst             39
# 18         Far Rockaway             35
# 19   Financial District            100
# 20             Flatbush             23
# 21            Flatlands             21
# 22         Forest Hills             39
# 23          Fort Greene             80
# 24        Fresh Meadows             15
# 25            Gravesend             27
# 26    Greenwich Village            100
# 27               Hollis             15
# 28               Inwood             58
# 29      Jackson Heights             80
# 30           Kensington             36
# 31          Kingsbridge             71
# 32         Little Italy            100
# 33      Lower East Side             60
# 34          Marble Hill             26
# 35              Maspeth             31
# 36  Morningside Heights             40
# 37          Murray Hill            290
# 38           Park Slope             74
# 39     Prospect Heights             79
# 40       Queens Village             17
# 41             Red Hook             48
# 42            Rego Park             44
# 43       Sheepshead Bay             27
# 44      Stuyvesant Town             16
# 45      Upper West Side            100
# 46   Washington Heights             85
# 47         West Village            100
# 48         Williamsburg             32
# 49             Woodside             80

# %% [markdown]
# Now it is time to complete the data collection and cleaning process by finally merging the venue data with the NYC dataframe

# %%
NYC = pd.merge(NYC, NYCVENUES, on = 'Neighborhood')
NYC
# Out:
#            Neighborhood  Rent  Num_of_Crimes        Borough   Latitude  \
# 0                Hollis  1037              2         Queens  40.711243
# 1           Murray Hill  1719              1      Manhattan  40.748303
# 2           Murray Hill  1719              1         Queens  40.764126
# 3           Murray Hill  4022              1      Manhattan  40.748303
# 4           Murray Hill  4022              1         Queens  40.764126
# 5         College Point  1719              2         Queens  40.784903
# 6         Fresh Meadows  1766              1         Queens  40.734394
# 7                Corona  1917              5         Queens  40.742382
# 8              Elmhurst  1922              6         Queens  40.744049
# 9         East Elmhurst  1936              7         Queens  40.764073
# 10             Woodside  1950              1         Queens  40.746349
# 11              Maspeth  1950              6         Queens  40.725427
# 12            Rego Park  2110              1         Queens  40.728974
# 13       Queens Village  2160              1         Queens  40.718893
# 14         Far Rockaway  2162              3         Queens  40.603134
# 15      Jackson Heights  2222              2         Queens  40.751981
# 16         Forest Hills  2558             10         Queens  40.725264
# 17            Flatlands  1492              2       Brooklyn  40.630446
# 18          Bensonhurst  1795              6       Brooklyn  40.611009
# 19           Bath Beach  1795              2       Brooklyn  40.599519
# 20           Kensington  1839              3       Brooklyn  40.642382
# 21            Gravesend  1840              8       Brooklyn  40.595260
# 22        Crown Heights  1853             10       Brooklyn  40.670829
# 23         Borough Park  1898              4       Brooklyn  40.633131
# 24             Flatbush  2009             12       Brooklyn  40.636326
# 25       Sheepshead Bay  2131              2       Brooklyn  40.586890
# 26        East Flatbush  2178             11       Brooklyn  40.641718
# 27             Canarsie  2178              2       Brooklyn  40.635564
# 28       Brighton Beach  2214              1       Brooklyn  40.576825
# 29         Clinton Hill  2671              3       Brooklyn  40.693229
# 30             Red Hook  2916              2       Brooklyn  40.676253
# 31             Bushwick  3065             15       Brooklyn  40.698116
# 32         Williamsburg  3247              9       Brooklyn  40.707144
# 33     Prospect Heights  3373              3       Brooklyn  40.676822
# 34          Fort Greene  3403              5       Brooklyn  40.688527
# 35     Brooklyn Heights  3456              1       Brooklyn  40.695864
# 36           Park Slope  3513              2       Brooklyn  40.672321
# 37          Kingsbridge  1694             11          Bronx  40.881687
# 38          Marble Hill  1694              1      Manhattan  40.876551
# 39               Inwood  2225              4      Manhattan  40.867684
# 40   Washington Heights  2243             15      Manhattan  40.851903
# 41          East Harlem  3334             16      Manhattan  40.792249
# 42      Stuyvesant Town  3720              2      Manhattan  40.731000
# 43   Financial District  4005              1      Manhattan  40.707107
# 44         Civic Center  4241              2      Manhattan  40.715229
# 45  Morningside Heights  4314              3      Manhattan  40.808000
# 46         East Village  4334              6      Manhattan  40.727847
# 47              Chelsea  4359             10      Manhattan  40.744035
# 48              Chelsea  4359             10  Staten Island  40.594726
# 49    Greenwich Village  4415              4      Manhattan  40.726933
# 50      Lower East Side  4516              9      Manhattan  40.717807
# 51         West Village  4524              5      Manhattan  40.734434
# 52      Upper West Side  4654             16      Manhattan  40.787658
# 53         Little Italy  4845              2      Manhattan  40.719324
#
#     Longitude  Num of Venues
# 0  -73.759250             15
# 1  -73.978332            290
# 2  -73.812763            290
# 3  -73.978332            290
# 4  -73.812763            290
# 5  -73.843045             41
# 6  -73.782713             15
# 7  -73.856825             17
# 8  -73.881656             39
# 9  -73.867041             14
# 10 -73.901842             80
# 11 -73.896217             31
# 12 -73.857827             44
# 13 -73.738715             17
# 14 -73.754980             35
# 15 -73.882821             80
# 16 -73.844475             39
# 17 -73.929113             21
# 18 -73.995180             37
# 19 -73.998752             47
# 20 -73.980421             36
# 21 -73.973471             27
# 22 -73.943291             20
# 23 -73.990498             20
# 24 -73.958401             23
# 25 -73.943186             27
# 26 -73.936103             13
# 27 -73.902093              6
# 28 -73.965094             42
# 29 -73.967843             96
# 30 -74.012759             48
# 31 -73.925258             76
# 32 -73.958115             32
# 33 -73.964859             79
# 34 -73.972906             80
# 35 -73.993782            100
# 36 -73.977050             74
# 37 -73.902818             71
# 38 -73.910660             26
# 39 -73.921210             58
# 40 -73.936900             85
# 41 -73.944182             44
# 42 -73.974052             16
# 43 -74.010665            100
# 44 -74.005415            100
# 45 -73.963896             40
# 46 -73.982226            100
# 47 -74.003116            104
# 48 -74.189560            104
# 49 -73.999914            100
# 50 -73.980890             60
# 51 -74.006180            100
# 52 -73.977059            100
# 53 -73.997305            100

# %% [markdown]
# Looking at the data we can see that Murray Hill is repeated 4 times and its number of venues is much larger than the rest of the neighborhoods. For this reason I have decided to remove it

# %%
NYC.drop([1,2,3,4], axis = 0, inplace = True)

# %%
NYC.reset_index(inplace = True, drop = True)
NYC
# Out:
#            Neighborhood  Rent  Num_of_Crimes        Borough   Latitude  \
# 0                Hollis  1037              2         Queens  40.711243
# 1         College Point  1719              2         Queens  40.784903
# 2         Fresh Meadows  1766              1         Queens  40.734394
# 3                Corona  1917              5         Queens  40.742382
# 4              Elmhurst  1922              6         Queens  40.744049
# 5         East Elmhurst  1936              7         Queens  40.764073
# 6              Woodside  1950              1         Queens  40.746349
# 7               Maspeth  1950              6         Queens  40.725427
# 8             Rego Park  2110              1         Queens  40.728974
# 9        Queens Village  2160              1         Queens  40.718893
# 10         Far Rockaway  2162              3         Queens  40.603134
# 11      Jackson Heights  2222              2         Queens  40.751981
# 12         Forest Hills  2558             10         Queens  40.725264
# 13            Flatlands  1492              2       Brooklyn  40.630446
# 14          Bensonhurst  1795              6       Brooklyn  40.611009
# 15           Bath Beach  1795              2       Brooklyn  40.599519
# 16           Kensington  1839              3       Brooklyn  40.642382
# 17            Gravesend  1840              8       Brooklyn  40.595260
# 18        Crown Heights  1853             10       Brooklyn  40.670829
# 19         Borough Park  1898              4       Brooklyn  40.633131
# 20             Flatbush  2009             12       Brooklyn  40.636326
# 21       Sheepshead Bay  2131              2       Brooklyn  40.586890
# 22        East Flatbush  2178             11       Brooklyn  40.641718
# 23             Canarsie  2178              2       Brooklyn  40.635564
# 24       Brighton Beach  2214              1       Brooklyn  40.576825
# 25         Clinton Hill  2671              3       Brooklyn  40.693229
# 26             Red Hook  2916              2       Brooklyn  40.676253
# 27             Bushwick  3065             15       Brooklyn  40.698116
# 28         Williamsburg  3247              9       Brooklyn  40.707144
# 29     Prospect Heights  3373              3       Brooklyn  40.676822
# 30          Fort Greene  3403              5       Brooklyn  40.688527
# 31     Brooklyn Heights  3456              1       Brooklyn  40.695864
# 32           Park Slope  3513              2       Brooklyn  40.672321
# 33          Kingsbridge  1694             11          Bronx  40.881687
# 34          Marble Hill  1694              1      Manhattan  40.876551
# 35               Inwood  2225              4      Manhattan  40.867684
# 36   Washington Heights  2243             15      Manhattan  40.851903
# 37          East Harlem  3334             16      Manhattan  40.792249
# 38      Stuyvesant Town  3720              2      Manhattan  40.731000
# 39   Financial District  4005              1      Manhattan  40.707107
# 40         Civic Center  4241              2      Manhattan  40.715229
# 41  Morningside Heights  4314              3      Manhattan  40.808000
# 42         East Village  4334              6      Manhattan  40.727847
# 43              Chelsea  4359             10      Manhattan  40.744035
# 44              Chelsea  4359             10  Staten Island  40.594726
# 45    Greenwich Village  4415              4      Manhattan  40.726933
# 46      Lower East Side  4516              9      Manhattan  40.717807
# 47         West Village  4524              5      Manhattan  40.734434
# 48      Upper West Side  4654             16      Manhattan  40.787658
# 49         Little Italy  4845              2      Manhattan  40.719324
#
#     Longitude  Num of Venues
# 0  -73.759250             15
# 1  -73.843045             41
# 2  -73.782713             15
# 3  -73.856825             17
# 4  -73.881656             39
# 5  -73.867041             14
# 6  -73.901842             80
# 7  -73.896217             31
# 8  -73.857827             44
# 9  -73.738715             17
# 10 -73.754980             35
# 11 -73.882821             80
# 12 -73.844475             39
# 13 -73.929113             21
# 14 -73.995180             37
# 15 -73.998752             47
# 16 -73.980421             36
# 17 -73.973471             27
# 18 -73.943291             20
# 19 -73.990498             20
# 20 -73.958401             23
# 21 -73.943186             27
# 22 -73.936103             13
# 23 -73.902093              6
# 24 -73.965094             42
# 25 -73.967843             96
# 26 -74.012759             48
# 27 -73.925258             76
# 28 -73.958115             32
# 29 -73.964859             79
# 30 -73.972906             80
# 31 -73.993782            100
# 32 -73.977050             74
# 33 -73.902818             71
# 34 -73.910660             26
# 35 -73.921210             58
# 36 -73.936900             85
# 37 -73.944182             44
# 38 -73.974052             16
# 39 -74.010665            100
# 40 -74.005415            100
# 41 -73.963896             40
# 42 -73.982226            100
# 43 -74.003116            104
# 44 -74.189560            104
# 45 -73.999914            100
# 46 -73.980890             60
# 47 -74.006180            100
# 48 -73.977059            100
# 49 -73.997305            100

# %% [markdown]
# Now we can say that the data cleaing process is fully complete

# %% [markdown]
# # Introducing the Livability Index
# The livability index is calculated from the crime rate, the average rent, and the popularity of a neighborhood (number of venues)
# We first need to normalize the data before finding the livability index

# %%
# Normalizing the data. Note: The rent and  the number of crimes are negative because we want the
# livability index to be higher when they are low
normal_Rent = preprocessing.normalize(-NYC[['Rent']], axis = 0)
normal_Crimes = preprocessing.normalize(-NYC[['Num_of_Crimes']], axis = 0)
normal_Venues = preprocessing.normalize(NYC[['Num of Venues']], axis = 0)

# Creating a normal dataframe to calculate the livability index
normal_NYC = pd.DataFrame()
normal_NYC['Rent'] = normal_Rent.reshape(50,)
normal_NYC['Num_of_Crimes'] =  normal_Crimes.reshape(50,)
normal_NYC['Num of Venues'] = normal_Venues.reshape(50,)

# %% [markdown]
# The livability index is simply the sum of the normalized data

# %%
normal_NYC['Livability Index'] = normal_NYC.sum(axis = 1)

# %%
normal_NYC
# Out:
#         Rent  Num_of_Crimes  Num of Venues  Livability Index
# 0  -0.049721      -0.040902       0.033994         -0.056629
# 1  -0.082421      -0.040902       0.092917         -0.030406
# 2  -0.084675      -0.020451       0.033994         -0.071132
# 3  -0.091915      -0.102254       0.038526         -0.155642
# 4  -0.092154      -0.122705       0.088384         -0.126475
# 5  -0.092826      -0.143156       0.031728         -0.204254
# 6  -0.093497      -0.020451       0.181301          0.067353
# 7  -0.093497      -0.122705       0.070254         -0.145948
# 8  -0.101169      -0.020451       0.099715         -0.021904
# 9  -0.103566      -0.020451       0.038526         -0.085490
# 10 -0.103662      -0.061352       0.079319         -0.085695
# 11 -0.106539      -0.040902       0.181301          0.033860
# 12 -0.122649      -0.204508       0.088384         -0.238773
# 13 -0.071537      -0.040902       0.047591         -0.064847
# 14 -0.086065      -0.122705       0.083852         -0.124918
# 15 -0.086065      -0.040902       0.106514         -0.020453
# 16 -0.088175      -0.061352       0.081585         -0.067942
# 17 -0.088223      -0.163606       0.061189         -0.190640
# 18 -0.088846      -0.204508       0.045325         -0.248029
# 19 -0.091004      -0.081803       0.045325         -0.127482
# 20 -0.096326      -0.245410       0.052124         -0.289612
# 21 -0.102175      -0.040902       0.061189         -0.081888
# 22 -0.104429      -0.224959       0.029461         -0.299926
# 23 -0.104429      -0.040902       0.013598         -0.131733
# 24 -0.106155      -0.020451       0.095183         -0.031423
# 25 -0.128067      -0.061352       0.217561          0.028141
# 26 -0.139814      -0.040902       0.108780         -0.071935
# 27 -0.146958      -0.306762       0.172236         -0.281484
# 28 -0.155684      -0.184057       0.072520         -0.267221
# 29 -0.161726      -0.061352       0.179034         -0.044044
# 30 -0.163164      -0.102254       0.181301         -0.084118
# 31 -0.165705      -0.020451       0.226626          0.040470
# 32 -0.168438      -0.040902       0.167703         -0.041637
# 33 -0.081223      -0.224959       0.160904         -0.145277
# 34 -0.081223      -0.020451       0.058923         -0.042751
# 35 -0.106682      -0.081803       0.131443         -0.057043
# 36 -0.107546      -0.306762       0.192632         -0.221676
# 37 -0.159856      -0.327213       0.099715         -0.387353
# 38 -0.178363      -0.040902       0.036260         -0.183005
# 39 -0.192028      -0.020451       0.226626          0.014147
# 40 -0.203344      -0.040902       0.226626         -0.017620
# 41 -0.206844      -0.061352       0.090650         -0.177546
# 42 -0.207803      -0.122705       0.226626         -0.103882
# 43 -0.209002      -0.204508       0.235691         -0.177819
# 44 -0.209002      -0.204508       0.235691         -0.177819
# 45 -0.211687      -0.081803       0.226626         -0.066864
# 46 -0.216529      -0.184057       0.135975         -0.264611
# 47 -0.216913      -0.102254       0.226626         -0.092541
# 48 -0.223146      -0.327213       0.226626         -0.323733
# 49 -0.232304      -0.040902       0.226626         -0.046580

# %% [markdown]
# Now we add the livability index to the NYC dataframe and sort by the livability index in descending order to get the best neighborhood

# %%
NYC['Livability Index'] = normal_NYC['Livability Index']
NYC
# Out:
#            Neighborhood  Rent  Num_of_Crimes        Borough   Latitude  \
# 0                Hollis  1037              2         Queens  40.711243
# 1         College Point  1719              2         Queens  40.784903
# 2         Fresh Meadows  1766              1         Queens  40.734394
# 3                Corona  1917              5         Queens  40.742382
# 4              Elmhurst  1922              6         Queens  40.744049
# 5         East Elmhurst  1936              7         Queens  40.764073
# 6              Woodside  1950              1         Queens  40.746349
# 7               Maspeth  1950              6         Queens  40.725427
# 8             Rego Park  2110              1         Queens  40.728974
# 9        Queens Village  2160              1         Queens  40.718893
# 10         Far Rockaway  2162              3         Queens  40.603134
# 11      Jackson Heights  2222              2         Queens  40.751981
# 12         Forest Hills  2558             10         Queens  40.725264
# 13            Flatlands  1492              2       Brooklyn  40.630446
# 14          Bensonhurst  1795              6       Brooklyn  40.611009
# 15           Bath Beach  1795              2       Brooklyn  40.599519
# 16           Kensington  1839              3       Brooklyn  40.642382
# 17            Gravesend  1840              8       Brooklyn  40.595260
# 18        Crown Heights  1853             10       Brooklyn  40.670829
# 19         Borough Park  1898              4       Brooklyn  40.633131
# 20             Flatbush  2009             12       Brooklyn  40.636326
# 21       Sheepshead Bay  2131              2       Brooklyn  40.586890
# 22        East Flatbush  2178             11       Brooklyn  40.641718
# 23             Canarsie  2178              2       Brooklyn  40.635564
# 24       Brighton Beach  2214              1       Brooklyn  40.576825
# 25         Clinton Hill  2671              3       Brooklyn  40.693229
# 26             Red Hook  2916              2       Brooklyn  40.676253
# 27             Bushwick  3065             15       Brooklyn  40.698116
# 28         Williamsburg  3247              9       Brooklyn  40.707144
# 29     Prospect Heights  3373              3       Brooklyn  40.676822
# 30          Fort Greene  3403              5       Brooklyn  40.688527
# 31     Brooklyn Heights  3456              1       Brooklyn  40.695864
# 32           Park Slope  3513              2       Brooklyn  40.672321
# 33          Kingsbridge  1694             11          Bronx  40.881687
# 34          Marble Hill  1694              1      Manhattan  40.876551
# 35               Inwood  2225              4      Manhattan  40.867684
# 36   Washington Heights  2243             15      Manhattan  40.851903
# 37          East Harlem  3334             16      Manhattan  40.792249
# 38      Stuyvesant Town  3720              2      Manhattan  40.731000
# 39   Financial District  4005              1      Manhattan  40.707107
# 40         Civic Center  4241              2      Manhattan  40.715229
# 41  Morningside Heights  4314              3      Manhattan  40.808000
# 42         East Village  4334              6      Manhattan  40.727847
# 43              Chelsea  4359             10      Manhattan  40.744035
# 44              Chelsea  4359             10  Staten Island  40.594726
# 45    Greenwich Village  4415              4      Manhattan  40.726933
# 46      Lower East Side  4516              9      Manhattan  40.717807
# 47         West Village  4524              5      Manhattan  40.734434
# 48      Upper West Side  4654             16      Manhattan  40.787658
# 49         Little Italy  4845              2      Manhattan  40.719324
#
#     Longitude  Num of Venues  Livability Index
# 0  -73.759250             15         -0.056629
# 1  -73.843045             41         -0.030406
# 2  -73.782713             15         -0.071132
# 3  -73.856825             17         -0.155642
# 4  -73.881656             39         -0.126475
# 5  -73.867041             14         -0.204254
# 6  -73.901842             80          0.067353
# 7  -73.896217             31         -0.145948
# 8  -73.857827             44         -0.021904
# 9  -73.738715             17         -0.085490
# 10 -73.754980             35         -0.085695
# 11 -73.882821             80          0.033860
# 12 -73.844475             39         -0.238773
# 13 -73.929113             21         -0.064847
# 14 -73.995180             37         -0.124918
# 15 -73.998752             47         -0.020453
# 16 -73.980421             36         -0.067942
# 17 -73.973471             27         -0.190640
# 18 -73.943291             20         -0.248029
# 19 -73.990498             20         -0.127482
# 20 -73.958401             23         -0.289612
# 21 -73.943186             27         -0.081888
# 22 -73.936103             13         -0.299926
# 23 -73.902093              6         -0.131733
# 24 -73.965094             42         -0.031423
# 25 -73.967843             96          0.028141
# 26 -74.012759             48         -0.071935
# 27 -73.925258             76         -0.281484
# 28 -73.958115             32         -0.267221
# 29 -73.964859             79         -0.044044
# 30 -73.972906             80         -0.084118
# 31 -73.993782            100          0.040470
# 32 -73.977050             74         -0.041637
# 33 -73.902818             71         -0.145277
# 34 -73.910660             26         -0.042751
# 35 -73.921210             58         -0.057043
# 36 -73.936900             85         -0.221676
# 37 -73.944182             44         -0.387353
# 38 -73.974052             16         -0.183005
# 39 -74.010665            100          0.014147
# 40 -74.005415            100         -0.017620
# 41 -73.963896             40         -0.177546
# 42 -73.982226            100         -0.103882
# 43 -74.003116            104         -0.177819
# 44 -74.189560            104         -0.177819
# 45 -73.999914            100         -0.066864
# 46 -73.980890             60         -0.264611
# 47 -74.006180            100         -0.092541
# 48 -73.977059            100         -0.323733
# 49 -73.997305            100         -0.046580

# %%
NYC.sort_values(by = 'Livability Index', axis = 0, ascending = False)
# Out:
#            Neighborhood  Rent  Num_of_Crimes        Borough   Latitude  \
# 6              Woodside  1950              1         Queens  40.746349
# 31     Brooklyn Heights  3456              1       Brooklyn  40.695864
# 11      Jackson Heights  2222              2         Queens  40.751981
# 25         Clinton Hill  2671              3       Brooklyn  40.693229
# 39   Financial District  4005              1      Manhattan  40.707107
# 40         Civic Center  4241              2      Manhattan  40.715229
# 15           Bath Beach  1795              2       Brooklyn  40.599519
# 8             Rego Park  2110              1         Queens  40.728974
# 1         College Point  1719              2         Queens  40.784903
# 24       Brighton Beach  2214              1       Brooklyn  40.576825
# 32           Park Slope  3513              2       Brooklyn  40.672321
# 34          Marble Hill  1694              1      Manhattan  40.876551
# 29     Prospect Heights  3373              3       Brooklyn  40.676822
# 49         Little Italy  4845              2      Manhattan  40.719324
# 0                Hollis  1037              2         Queens  40.711243
# 35               Inwood  2225              4      Manhattan  40.867684
# 13            Flatlands  1492              2       Brooklyn  40.630446
# 45    Greenwich Village  4415              4      Manhattan  40.726933
# 16           Kensington  1839              3       Brooklyn  40.642382
# 2         Fresh Meadows  1766              1         Queens  40.734394
# 26             Red Hook  2916              2       Brooklyn  40.676253
# 21       Sheepshead Bay  2131              2       Brooklyn  40.586890
# 30          Fort Greene  3403              5       Brooklyn  40.688527
# 9        Queens Village  2160              1         Queens  40.718893
# 10         Far Rockaway  2162              3         Queens  40.603134
# 47         West Village  4524              5      Manhattan  40.734434
# 42         East Village  4334              6      Manhattan  40.727847
# 14          Bensonhurst  1795              6       Brooklyn  40.611009
# 4              Elmhurst  1922              6         Queens  40.744049
# 19         Borough Park  1898              4       Brooklyn  40.633131
# 23             Canarsie  2178              2       Brooklyn  40.635564
# 33          Kingsbridge  1694             11          Bronx  40.881687
# 7               Maspeth  1950              6         Queens  40.725427
# 3                Corona  1917              5         Queens  40.742382
# 41  Morningside Heights  4314              3      Manhattan  40.808000
# 44              Chelsea  4359             10  Staten Island  40.594726
# 43              Chelsea  4359             10      Manhattan  40.744035
# 38      Stuyvesant Town  3720              2      Manhattan  40.731000
# 17            Gravesend  1840              8       Brooklyn  40.595260
# 5         East Elmhurst  1936              7         Queens  40.764073
# 36   Washington Heights  2243             15      Manhattan  40.851903
# 12         Forest Hills  2558             10         Queens  40.725264
# 18        Crown Heights  1853             10       Brooklyn  40.670829
# 46      Lower East Side  4516              9      Manhattan  40.717807
# 28         Williamsburg  3247              9       Brooklyn  40.707144
# 27             Bushwick  3065             15       Brooklyn  40.698116
# 20             Flatbush  2009             12       Brooklyn  40.636326
# 22        East Flatbush  2178             11       Brooklyn  40.641718
# 48      Upper West Side  4654             16      Manhattan  40.787658
# 37          East Harlem  3334             16      Manhattan  40.792249
#
#     Longitude  Num of Venues  Livability Index
# 6  -73.901842             80          0.067353
# 31 -73.993782            100          0.040470
# 11 -73.882821             80          0.033860
# 25 -73.967843             96          0.028141
# 39 -74.010665            100          0.014147
# 40 -74.005415            100         -0.017620
# 15 -73.998752             47         -0.020453
# 8  -73.857827             44         -0.021904
# 1  -73.843045             41         -0.030406
# 24 -73.965094             42         -0.031423
# 32 -73.977050             74         -0.041637
# 34 -73.910660             26         -0.042751
# 29 -73.964859             79         -0.044044
# 49 -73.997305            100         -0.046580
# 0  -73.759250             15         -0.056629
# 35 -73.921210             58         -0.057043
# 13 -73.929113             21         -0.064847
# 45 -73.999914            100         -0.066864
# 16 -73.980421             36         -0.067942
# 2  -73.782713             15         -0.071132
# 26 -74.012759             48         -0.071935
# 21 -73.943186             27         -0.081888
# 30 -73.972906             80         -0.084118
# 9  -73.738715             17         -0.085490
# 10 -73.754980             35         -0.085695
# 47 -74.006180            100         -0.092541
# 42 -73.982226            100         -0.103882
# 14 -73.995180             37         -0.124918
# 4  -73.881656             39         -0.126475
# 19 -73.990498             20         -0.127482
# 23 -73.902093              6         -0.131733
# 33 -73.902818             71         -0.145277
# 7  -73.896217             31         -0.145948
# 3  -73.856825             17         -0.155642
# 41 -73.963896             40         -0.177546
# 44 -74.189560            104         -0.177819
# 43 -74.003116            104         -0.177819
# 38 -73.974052             16         -0.183005
# 17 -73.973471             27         -0.190640
# 5  -73.867041             14         -0.204254
# 36 -73.936900             85         -0.221676
# 12 -73.844475             39         -0.238773
# 18 -73.943291             20         -0.248029
# 46 -73.980890             60         -0.264611
# 28 -73.958115             32         -0.267221
# 27 -73.925258             76         -0.281484
# 20 -73.958401             23         -0.289612
# 22 -73.936103             13         -0.299926
# 48 -73.977059            100         -0.323733
# 37 -73.944182             44         -0.387353

# %% [markdown]
# Lets take a closer look at the top value

# %%
NYC.loc[NYC['Neighborhood'] == 'Clinton Hill']
# Out:
#     Neighborhood  Rent  Num_of_Crimes   Borough   Latitude  Longitude  \
# 25  Clinton Hill  2671              3  Brooklyn  40.693229 -73.967843
#
#     Num of Venues  Livability Index
# 25             96          0.028141

# %% [markdown]
# The rent is reasonable for New York, the number of crimes is very low at 1, and there are 96 venues in the vicinity. It seems to me that Clinton Hill is a very good neighborhood to live in and might be one of the best

# %% [markdown]
# # Using a Different Metric

# %% [markdown]
# This was a very simple analysis. Lets take a look at this site : https://www.niche.com/places-to-live/search/best-neighborhoods/m/new-york-city-metro-area/ which ranks the best New York neighborhoods to live in using a much more complicated method than what I did. We will need to scrape the dataset from their website

# %%
ranking = []
for i in range(1,13):
    source = requests.get(f'https://www.niche.com/places-to-live/search/best-neighborhoods/m/new-york-city-metro-area//?page={i}', headers = {'User-Agent': 'Mozilla/5.0'}).text
    soup = BeautifulSoup(source, 'lxml')
    for i in soup.find_all(class_ = 'search-result__title'):
        ranking.append(i.text)

# %%
rankingdf = pd.DataFrame()
rankingdf['Neighborhood'] = ranking

# %%
rankingdf['Rank'] = range(1,len(rankingdf['Neighborhood']) + 1)
rankingdf
# Out:
#                             Neighborhood  Rank
# 0                               Kips Bay     1
# 1                            Murray Hill     2
# 2                                Chelsea     3
# 3                     Financial District     4
# 4                      Battery Park City     5
# 5                      Greenwich Village     6
# 6                       Prospect Heights     7
# 7                       Brooklyn Heights     8
# 8                         Hell's Kitchen     9
# 9                                   NoHo    10
# 10                            Waterfront    11
# 11                               Midtown    12
# 12                                Nolita    13
# 13                                  SoHo    14
# 14                     Flatiron District    15
# 15                              Gramercy    16
# 16                               Tribeca    17
# 17                            Park Slope    18
# 18                     Downtown Brooklyn    19
# 19                       Upper West Side    20
# 20                      Theater District    21
# 21                             Fieldston    22
# 22                          West Village    23
# 23   Columbia Street Waterfront District    24
# 24                           Cobble Hill    25
# 25                           South Slope    26
# 26                       Upper East Side    27
# 27                   Morningside Heights    28
# 28                       Windsor Terrace    29
# 29                                 DUMBO    30
# ..                                   ...   ...
# 246                            Soundview   247
# 247                      East Morrisania   248
# 248                           West Farms   249
# 249                         Clason Point   250
# 250                          Castle Hill   251
# 251                              Tremont   252
# 252                        East New York   253
# 253                      South Ironbound   254
# 254                          Brownsville   255
# 255                Dayton/Weequahic Park   256
# 256                      Upper Roseville   257
# 257                  Springfield/Belmont   258
# 258                      Lower Roseville   259
# 259                       North Broadway   260
# 260                            Fairmount   261
# 261                      Lower Vailsburg   262
# 262                   South Broad Street   263
# 263        Mount Pleasant/Lower Broadway   264
# 264                   Lower Clinton Hill   265
# 265                            Weequahic   266
# 266                   Upper Clinton Hill   267
# 267                            West Side   268
# 268                      Stuyvesant Town   269
# 269                     Randall's Island   270
# 270                           Mount Eden   271
# 271                           Charleston   272
# 272                   University Heights   273
# 273       Newark Airport and Port Newark   274
# 274                        Liberty State   275
# 275                                 Cove   276
#
# [276 rows x 2 columns]

# %%
NYC_Ranked = pd.merge(NYC, rankingdf, on = 'Neighborhood')

# %% [markdown]
# Lets see what the top ranked neighborhood is according to niche.com

# %%
NYC_Ranked2 = NYC_Ranked.sort_values(by = 'Rank')

# %% [markdown]
# The top ranked neighborhood according to niche.com is Chelsea.

# %% [markdown]
# # Relationships Between Variables

# %%
NYC_Ranked2.reset_index(drop = True)
# Out:
#            Neighborhood  Rent  Num_of_Crimes        Borough   Latitude  \
# 0               Chelsea  4359             10  Staten Island  40.594726
# 1               Chelsea  4359             10      Manhattan  40.744035
# 2    Financial District  4005              1      Manhattan  40.707107
# 3     Greenwich Village  4415              4      Manhattan  40.726933
# 4      Prospect Heights  3373              3       Brooklyn  40.676822
# 5      Brooklyn Heights  3456              1       Brooklyn  40.695864
# 6            Park Slope  3513              2       Brooklyn  40.672321
# 7       Upper West Side  4654             16      Manhattan  40.787658
# 8          West Village  4524              5      Manhattan  40.734434
# 9   Morningside Heights  4314              3      Manhattan  40.808000
# 10         Civic Center  4241              2      Manhattan  40.715229
# 11         East Village  4334              6      Manhattan  40.727847
# 12         Little Italy  4845              2      Manhattan  40.719324
# 13         Clinton Hill  2671              3       Brooklyn  40.693229
# 14         Forest Hills  2558             10         Queens  40.725264
# 15      Lower East Side  4516              9      Manhattan  40.717807
# 16            Rego Park  2110              1         Queens  40.728974
# 17   Washington Heights  2243             15      Manhattan  40.851903
# 18          Fort Greene  3403              5       Brooklyn  40.688527
# 19           Kensington  1839              3       Brooklyn  40.642382
# 20               Inwood  2225              4      Manhattan  40.867684
# 21        Fresh Meadows  1766              1         Queens  40.734394
# 22         Williamsburg  3247              9       Brooklyn  40.707144
# 23          East Harlem  3334             16      Manhattan  40.792249
# 24       Sheepshead Bay  2131              2       Brooklyn  40.586890
# 25           Bath Beach  1795              2       Brooklyn  40.599519
# 26          Kingsbridge  1694             11          Bronx  40.881687
# 27             Woodside  1950              1         Queens  40.746349
# 28       Brighton Beach  2214              1       Brooklyn  40.576825
# 29          Bensonhurst  1795              6       Brooklyn  40.611009
# 30              Maspeth  1950              6         Queens  40.725427
# 31            Gravesend  1840              8       Brooklyn  40.595260
# 32            Flatlands  1492              2       Brooklyn  40.630446
# 33             Flatbush  2009             12       Brooklyn  40.636326
# 34        East Elmhurst  1936              7         Queens  40.764073
# 35             Elmhurst  1922              6         Queens  40.744049
# 36        Crown Heights  1853             10       Brooklyn  40.670829
# 37        College Point  1719              2         Queens  40.784903
# 38               Hollis  1037              2         Queens  40.711243
# 39         Borough Park  1898              4       Brooklyn  40.633131
# 40          Marble Hill  1694              1      Manhattan  40.876551
# 41       Queens Village  2160              1         Queens  40.718893
# 42             Red Hook  2916              2       Brooklyn  40.676253
# 43             Bushwick  3065             15       Brooklyn  40.698116
# 44      Jackson Heights  2222              2         Queens  40.751981
# 45         Far Rockaway  2162              3         Queens  40.603134
# 46               Corona  1917              5         Queens  40.742382
# 47             Canarsie  2178              2       Brooklyn  40.635564
# 48        East Flatbush  2178             11       Brooklyn  40.641718
# 49      Stuyvesant Town  3720              2      Manhattan  40.731000
#
#     Longitude  Num of Venues  Livability Index  Rank
# 0  -74.189560            104         -0.177819     3
# 1  -74.003116            104         -0.177819     3
# 2  -74.010665            100          0.014147     4
# 3  -73.999914            100         -0.066864     6
# 4  -73.964859             79         -0.044044     7
# 5  -73.993782            100          0.040470     8
# 6  -73.977050             74         -0.041637    18
# 7  -73.977059            100         -0.323733    20
# 8  -74.006180            100         -0.092541    23
# 9  -73.963896             40         -0.177546    28
# 10 -74.005415            100         -0.017620    33
# 11 -73.982226            100         -0.103882    35
# 12 -73.997305            100         -0.046580    38
# 13 -73.967843             96          0.028141    40
# 14 -73.844475             39         -0.238773    42
# 15 -73.980890             60         -0.264611    46
# 16 -73.857827             44         -0.021904    55
# 17 -73.936900             85         -0.221676    67
# 18 -73.972906             80         -0.084118    69
# 19 -73.980421             36         -0.067942    77
# 20 -73.921210             58         -0.057043    80
# 21 -73.782713             15         -0.071132    84
# 22 -73.958115             32         -0.267221    87
# 23 -73.944182             44         -0.387353   108
# 24 -73.943186             27         -0.081888   109
# 25 -73.998752             47         -0.020453   113
# 26 -73.902818             71         -0.145277   120
# 27 -73.901842             80          0.067353   130
# 28 -73.965094             42         -0.031423   133
# 29 -73.995180             37         -0.124918   134
# 30 -73.896217             31         -0.145948   136
# 31 -73.973471             27         -0.190640   148
# 32 -73.929113             21         -0.064847   150
# 33 -73.958401             23         -0.289612   157
# 34 -73.867041             14         -0.204254   158
# 35 -73.881656             39         -0.126475   162
# 36 -73.943291             20         -0.248029   164
# 37 -73.843045             41         -0.030406   169
# 38 -73.759250             15         -0.056629   172
# 39 -73.990498             20         -0.127482   180
# 40 -73.910660             26         -0.042751   182
# 41 -73.738715             17         -0.085490   184
# 42 -74.012759             48         -0.071935   191
# 43 -73.925258             76         -0.281484   201
# 44 -73.882821             80          0.033860   213
# 45 -73.754980             35         -0.085695   224
# 46 -73.856825             17         -0.155642   226
# 47 -73.902093              6         -0.131733   232
# 48 -73.936103             13         -0.299926   235
# 49 -73.974052             16         -0.183005   269
